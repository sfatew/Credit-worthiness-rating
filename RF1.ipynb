# %% [markdown]
# # Random Forest

# %% [markdown]
# ## 1. Introduction
# Credit classification is one of the popular classification problems encountered by financial institutions. For example, when customers applies for a loan, financial institutions such as banks would like to predict the probability of default. In this section, we will be using the german credit rating dataset provided by German Government. The data contains several attributes of persons who availed the credit.
#
# In this project, we will do Exploratory data analysis and we will build ``Random Forest``
#
#
#
#
#
#
#
#
#
# +++++++++ model to see class probability.

# %% [markdown]
# ## 2. Feature Description

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import math
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, StratifiedKFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from imblearn.over_sampling import SMOTE,ADASYN
import seaborn as sns
# Load Data 
data1 = pd.read_csv("data/german_credit.csv")
data1.head()
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# 1                     1                             3                    2
# 2                     2                             4                    2
# 3                     1                             3                    3
# 4                     1                             3                    4
#
#    Sex & Marital Status  ...  Duration in Current address  \
# 0                     2  ...                            4
# 1                     3  ...                            2
# 2                     2  ...                            4
# 3                     3  ...                            2
# 4                     3  ...                            4
#
#    Most valuable available asset  Age (years)  Concurrent Credits  \
# 0                              2           21                   3
# 1                              1           36                   3
# 2                              1           23                   3
# 3                              1           39                   3
# 4                              2           38                   1
#
#    Type of apartment  No of Credits at this Bank  Occupation  \
# 0                  1                           1           3
# 1                  1                           2           3
# 2                  1                           1           2
# 3                  1                           2           2
# 4                  2                           2           2
#
#    No of dependents  Telephone  Foreign Worker
# 0                 1          1               1
# 1                 2          1               1
# 2                 1          1               1
# 3                 2          1               2
# 4                 1          1               2
#
# [5 rows x 21 columns]

# %% [markdown]
# Categorical Variables:
# - ``Account Balance``: No account (1), None (No balance) (2), Below 200 DM (3), 200 DM or Above (4)
# - ``Payment Status``: Delayed (0), Other Credits (1), Paid Up (2), No Problems (in this bank) (3), Previous Credits Paid (4)
# - ``Savings/Stock Value``: None (1), Below 100 DM (2), [100, 500) DM (3), [500,1000) DM (4), Above 1000 DM (5)
# - ``Employment Length``: None (1), Below 1 year (2) , [1, 4) (3) , [4, 7) (4), Above 7 (5)
# - ``Installments %``: Above 35% (1), [25%,35%) (2), [20%,25%) (3), Below 20% (4)
# - ``Occupation``: Unemployed, unskilled (1), Unskilled Permanent Resident (2), Skilled (3), Executive (4)
# - ``Sex/Marital Status``: Male Divorced (1), Male Single (2), Male Married/Widowed (3), Female (4)
# - ``No of Credits at this bank``: 1 (1), 2 or 3 (2), 4 or 5 (3), Above 6 (4)
# - ``Guarantor``: None (1), Co - applicant (2), Guarantor (3)
# - ``Concurrent Credits``: Other Banks (1), Dept Stores (2), None (3)
# - ``Foreign Worker``: Yes (1), No (2)
# - ``Purpose of Credit``: New car (1), Used car (2), Furniture (3), Radio/TV (4), Appliances (5), Repair (6), Education (7), Vacation (8), Retraining (9), Business (10), Other (0)
# - ``Type of Apartment``: Free (1), Rented (2), Owned (3)
# - ``Most Valuable Asset``: None (1), Car (2), Life Insurance (3), Real Estate (4)
# - ``No. of Departments``: 3 or More	(1), Less than 3 (2)
# - ``Telephone``: Yes (1), No (2)
#
# Continuous Variables:
# - ``Duration of Credit (Month)``
# - ``Amount of Credit (DM)``
# - ``Age (of Appicant)``

# %% [markdown]
# ## 3. Exploratory data analysis

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   int64
#  1   Account Balance                    1000 non-null   int64
#  2   Duration of Credit (month)         1000 non-null   int64
#  3   Payment Status of Previous Credit  1000 non-null   int64
#  4   Purpose                            1000 non-null   int64
#  5   Credit Amount                      1000 non-null   int64
#  6   Value Savings/Stocks               1000 non-null   int64
#  7   Length of current employment       1000 non-null   int64
#  8   Instalment per cent                1000 non-null   int64
#  9   Sex & Marital Status               1000 non-null   int64
#  10  Guarantors                         1000 non-null   int64
#  11  Duration in Current address        1000 non-null   int64
#  12  Most valuable available asset      1000 non-null   int64
#  13  Age (years)                        1000 non-null   int64
#  14  Concurrent Credits                 1000 non-null   int64
#  15  Type of apartment                  1000 non-null   int64
#  16  No of Credits at this Bank         1000 non-null   int64
#  17  Occupation                         1000 non-null   int64
#  18  No of dependents                   1000 non-null   int64
#  19  Telephone                          1000 non-null   int64
#  20  Foreign Worker                     1000 non-null   int64
# dtypes: int64(21)
# memory usage: 164.2 KB

# %%
data1.shape
# Out:
# (1000, 21)

# %%
data1.describe()
# Out:
#        Creditability  Account Balance  Duration of Credit (month)  \
# count    1000.000000      1000.000000                 1000.000000
# mean        0.700000         2.577000                   20.903000
# std         0.458487         1.257638                   12.058814
# min         0.000000         1.000000                    4.000000
# 25%         0.000000         1.000000                   12.000000
# 50%         1.000000         2.000000                   18.000000
# 75%         1.000000         4.000000                   24.000000
# max         1.000000         4.000000                   72.000000
#
#        Payment Status of Previous Credit      Purpose  Credit Amount  \
# count                         1000.00000  1000.000000     1000.00000
# mean                             2.54500     2.828000     3271.24800
# std                              1.08312     2.744439     2822.75176
# min                              0.00000     0.000000      250.00000
# 25%                              2.00000     1.000000     1365.50000
# 50%                              2.00000     2.000000     2319.50000
# 75%                              4.00000     3.000000     3972.25000
# max                              4.00000    10.000000    18424.00000
#
#        Value Savings/Stocks  Length of current employment  \
# count           1000.000000                   1000.000000
# mean               2.105000                      3.384000
# std                1.580023                      1.208306
# min                1.000000                      1.000000
# 25%                1.000000                      3.000000
# 50%                1.000000                      3.000000
# 75%                3.000000                      5.000000
# max                5.000000                      5.000000
#
#        Instalment per cent  Sex & Marital Status  ...  \
# count          1000.000000            1000.00000  ...
# mean              2.973000               2.68200  ...
# std               1.118715               0.70808  ...
# min               1.000000               1.00000  ...
# 25%               2.000000               2.00000  ...
# 50%               3.000000               3.00000  ...
# 75%               4.000000               3.00000  ...
# max               4.000000               4.00000  ...
#
#        Duration in Current address  Most valuable available asset  \
# count                  1000.000000                    1000.000000
# mean                      2.845000                       2.358000
# std                       1.103718                       1.050209
# min                       1.000000                       1.000000
# 25%                       2.000000                       1.000000
# 50%                       3.000000                       2.000000
# 75%                       4.000000                       3.000000
# max                       4.000000                       4.000000
#
#        Age (years)  Concurrent Credits  Type of apartment  \
# count   1000.00000         1000.000000        1000.000000
# mean      35.54200            2.675000           1.928000
# std       11.35267            0.705601           0.530186
# min       19.00000            1.000000           1.000000
# 25%       27.00000            3.000000           2.000000
# 50%       33.00000            3.000000           2.000000
# 75%       42.00000            3.000000           2.000000
# max       75.00000            3.000000           3.000000
#
#        No of Credits at this Bank   Occupation  No of dependents    Telephone  \
# count                 1000.000000  1000.000000       1000.000000  1000.000000
# mean                     1.407000     2.904000          1.155000     1.404000
# std                      0.577654     0.653614          0.362086     0.490943
# min                      1.000000     1.000000          1.000000     1.000000
# 25%                      1.000000     3.000000          1.000000     1.000000
# 50%                      1.000000     3.000000          1.000000     1.000000
# 75%                      2.000000     3.000000          1.000000     2.000000
# max                      4.000000     4.000000          2.000000     2.000000
#
#        Foreign Worker
# count     1000.000000
# mean         1.037000
# std          0.188856
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
#
# [8 rows x 21 columns]

# %%
# Checking the missing values values for customer data
print(data1.isnull().sum())
# Out:
# Creditability                        0
# Account Balance                      0
# Duration of Credit (month)           0
# Payment Status of Previous Credit    0
# Purpose                              0
# Credit Amount                        0
# Value Savings/Stocks                 0
# Length of current employment         0
# Instalment per cent                  0
# Sex & Marital Status                 0
# Guarantors                           0
# Duration in Current address          0
# Most valuable available asset        0
# Age (years)                          0
# Concurrent Credits                   0
# Type of apartment                    0
# No of Credits at this Bank           0
# Occupation                           0
# No of dependents                     0
# Telephone                            0
# Foreign Worker                       0
# dtype: int64

# %%
print(data1["Creditability"].value_counts())
#Visualising the label column
plt.pie(data1["Creditability"].value_counts(),labels = ["Good Credit", "Bad Credit"],colors =["green","red"], autopct = '%1.1f%%',radius = 1)
plt.legend(title= "Credit Scoring")
plt.show()
# Out:
# Creditability
# 1    700
# 0    300
# Name: count, dtype: int64

# %% [markdown]
# label is 1, the customer is in good credit , label is 0, the customer is in bad credit. The data is ``imbalance`` as we have more good credit than bad credit (7:3)

# %%
data1.nunique()
# Out:
# Creditability                          2
# Account Balance                        4
# Duration of Credit (month)            33
# Payment Status of Previous Credit      5
# Purpose                               10
# Credit Amount                        923
# Value Savings/Stocks                   5
# Length of current employment           5
# Instalment per cent                    4
# Sex & Marital Status                   4
# Guarantors                             3
# Duration in Current address            4
# Most valuable available asset          4
# Age (years)                           53
# Concurrent Credits                     3
# Type of apartment                      3
# No of Credits at this Bank             4
# Occupation                             4
# No of dependents                       2
# Telephone                              2
# Foreign Worker                         2
# dtype: int64

# %% [markdown]
# Distribution of the continuous variables

# %%
cont_num_col = ["Duration of Credit (month)","Credit Amount","Age (years)"]
fig, ax = plt.subplots(3, figsize=(10,15))
for idx, col in enumerate(cont_num_col):
    sns.histplot(data1[data1['Creditability'] == 1][col],
                 kde=False, 
                 label='Good Credit', 
                 ax=ax[idx],alpha =.8,zorder = 1)
    sns.histplot(data1[data1['Creditability'] == 0][col],
                 kde=False, 
                 label='Bad Credit', 
                 ax=ax[idx],zorder =2)
    ax[idx].legend(title='Creditability')
    ax[idx].set_xlabel(col)
    ax[idx].set_ylabel("Frequency")
    ax[idx].grid(visible=True, 
                 color='wheat', 
                 linestyle='--',zorder =0,alpha = 0.2)
    ax[idx].set_title("Distribution by {}".format(col))
plt.suptitle("Distribution of Duration, Credit Amount and Age by Credit Status", 
             fontsize=18, 
             fontweight='bold')
fig.tight_layout()
fig.subplots_adjust(top = 0.93,hspace = 0.3)
plt.show()

# %% [markdown]
# Since most of the predictors are categorical with several levels, the full cross-classification of all variables will lead to zero observations in many cells. Hence we need to reduce the table size.
# Depending on the cell proportions, two or more cells are merged for several categorical predictors and transform a continuous-valued variable into a discrete one by creating a set of contiguous intervals (or equivalently a set of cutpoints) that spans the range of the variable’s values (``Discretization``). We present below the final classification for the predictors that may potentially have any influence on Creditability:
#
# Categorical Variables:
#
# - ``Account Balance``: No account (1), None (No balance) (2), Some Balance (3)
# - ``Payment Status``: Some Problems (1), Paid Up (2), No Problems (in this bank) (3)
# - ``Savings/Stock Value``: None (1), Below 100 DM (2), $[100, 1000]$ DM (3), Above 1000 DM (4)
# - ``Employment Length``: Below 1 year (including unemployed) (1) , [1, 4) (2) , [4, 7) (3), Above 7 (4)
# - ``Installments %``: Above 35% (1), $[25,35)$ (2), $[20,25)$ (3), Below 20% (4)
# - ``Occupation``: Unemployed/unskilled (1), Skilled (2), Executive (3)
# - ``Sex/Marital Status``: Male Divorced/Single (1), Male Married/Widowed (2), Female (3)
# - ``No of Credits at this bank``: 1 (1), More than 1 (2)
# - ``Guarantor``: None (1), Yes (2)
# - ``Concurrent Credits``: Other Banks or Dept Stores (1), None (2)
# - ``ForeignWorker variable``: Yes (1), No (2)
# - ``Purpose of Credit``: New car (1), Used car (2), Home Related (3), Other (4)
# - ``Type of Apartment``: Free (1), Rented (2), Owned (3)
# - ``Most Valuable Asset``: None (1), Car (2), Life Insurance (3), Real Estate (4)
# - ``No.of Departments``: 3 or More (1), Less than 3 (2)
# - ``Telephone``: Yes (1), No (2)
#
# Continuous Variables:
# - ``Duration in months``: $[0,6]$, $(6,12]$, $(12,18]$, $(18,24]$, $(24,30]$, $(30,36]$, $(36,42]$, $(42,48]$, $(48,54]$, $(54,\infty)$
# - ``Amount of credit in DM``: $(0,500]$, $(500,1000]$, $(1000,1500]$, $(1500,2500]$, $(2500,5000]$, $(5000,7500]$, $(7500,10000]$, $(10000,15000]$, $(15000,20000]$, $(20000,\infty)$
# - ``Age in years``: $(0,25]$, $(25,39]$, $(39,59]$, $(59,64]$, $(65,\infty)$

# %%
# Function to replace values in specified columns
def replace_values(df, col_replacements):
    for col, replacements in col_replacements.items():
        df[col] = df[col].replace(replacements)
    return df

# Dictionary specifying the columns and their replacement values
col_replacements = {
    'Account Balance': {4: 3},
    'Payment Status of Previous Credit': {0: 1, 4: 3},
    'Value Savings/Stocks': {4: 3, 5: 4},
    'Length of current employment': {2: 1, 3: 2, 4: 3, 5: 4},
    'Occupation': {2: 1, 3: 2, 4: 3},
    'Sex & Marital Status': {2: 1, 3: 2, 4: 3},
    'No of Credits at this Bank': {3: 2, 4: 2},
    'Guarantors': {3: 2},
    'Concurrent Credits': {2: 1, 3: 2},
    'Purpose': {**{i: 3 for i in range(4, 7)}, **{j: 0 for j in range(7, 11)}}
}

# Apply replacements
data1 = replace_values(data1, col_replacements)

# Function to discretize continuous variables
def discretize_column(df, col, bins, labels):
    df[col] = pd.cut(df[col], bins=bins, labels=labels, right=False)
    return df

# Bins and labels for discretization
bins_labels = {
    'Duration of Credit (month)': {
        'bins': [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, float('inf')],
        'labels': [str(i) for i in range(1,11)]
    },
    'Credit Amount': {
        'bins': [0, 500, 1000, 1500, 2500, 5000, 7500, 10000, 15000, 20000, float('inf')],
        'labels': [str(i) for i in range(1,11)]
    },
    'Age (years)': {
        'bins': [0, 26, 40, 60, 65, float('inf')],
        'labels': [str(i) for i in range(1, 6)]
    }
}

# Apply discretization
for col, bl in bins_labels.items():
    data1 = discretize_column(data1, col, bl['bins'], bl['labels'])
print(pd.DataFrame(data1))
# Out:
#      Creditability  Account Balance Duration of Credit (month)  \
# 0                1                1                          4
# 1                1                1                          2
# 2                1                2                          3
# 3                1                1                          3
# 4                1                1                          3
# ..             ...              ...                        ...
# 995              0                1                          5
# 996              0                1                          5
# 997              0                3                          4
# 998              0                2                          3
# 999              0                1                          6
#
#      Payment Status of Previous Credit  Purpose Credit Amount  \
# 0                                    3        2             3
# 1                                    3        0             5
# 2                                    2        0             2
# 3                                    3        0             4
# 4                                    3        0             4
# ..                                 ...      ...           ...
# 995                                  2        3             4
# 996                                  2        0             4
# 997                                  3        0             8
# 998                                  2        3             6
# 999                                  2        2             6
#
#      Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                       1                             1                    4
# 1                       1                             2                    2
# 2                       2                             3                    2
# 3                       1                             2                    3
# 4                       1                             2                    4
# ..                    ...                           ...                  ...
# 995                     1                             2                    2
# 996                     1                             4                    4
# 997                     4                             4                    4
# 998                     4                             1                    2
# 999                     4                             4                    4
#
#      Sex & Marital Status  ...  Duration in Current address  \
# 0                       1  ...                            4
# 1                       2  ...                            2
# 2                       1  ...                            4
# 3                       2  ...                            2
# 4                       2  ...                            4
# ..                    ...  ...                          ...
# 995                     2  ...                            4
# 996                     2  ...                            1
# 997                     2  ...                            4
# 998                     2  ...                            1
# 999                     2  ...                            4
#
#      Most valuable available asset  Age (years) Concurrent Credits  \
# 0                                2            1                  2
# 1                                1            2                  2
# 2                                1            1                  2
# 3                                1            2                  2
# 4                                2            2                  1
# ..                             ...          ...                ...
# 995                              1            1                  2
# 996                              1            3                  2
# 997                              4            2                  2
# 998                              4            3                  2
# 999                              2            2                  2
#
#      Type of apartment  No of Credits at this Bank  Occupation  \
# 0                    1                           1           2
# 1                    1                           2           2
# 2                    1                           1           1
# 3                    1                           2           1
# 4                    2                           2           1
# ..                 ...                         ...         ...
# 995                  1                           1           1
# 996                  2                           1           2
# 997                  3                           1           3
# 998                  2                           1           3
# 999                  2                           1           2
#
#      No of dependents  Telephone  Foreign Worker
# 0                   1          1               1
# 1                   2          1               1
# 2                   1          1               1
# 3                   2          1               2
# 4                   1          1               2
# ..                ...        ...             ...
# 995                 2          1               1
# 996                 1          1               1
# 997                 1          2               1
# 998                 1          2               1
# 999                 1          1               1
#
# [1000 rows x 21 columns]

# %%
data1.nunique()
# Out:
# Creditability                         2
# Account Balance                       3
# Duration of Credit (month)           10
# Payment Status of Previous Credit     3
# Purpose                               4
# Credit Amount                         9
# Value Savings/Stocks                  4
# Length of current employment          4
# Instalment per cent                   4
# Sex & Marital Status                  3
# Guarantors                            2
# Duration in Current address           4
# Most valuable available asset         4
# Age (years)                           5
# Concurrent Credits                    2
# Type of apartment                     3
# No of Credits at this Bank            2
# Occupation                            3
# No of dependents                      2
# Telephone                             2
# Foreign Worker                        2
# dtype: int64

# %%
#Correlation Matrix 
correlation_matrix = data1.corr()
fig = plt.figure(figsize=(13,8))
heatmap=sns.heatmap(correlation_matrix,annot = True,square= True, linewidths=.5,cmap=plt.cm.Reds,annot_kws={"size":6}) 
plt.show()

# %%
cat_cols = data1.columns.drop(cont_num_col+['Creditability'])
fig, ax = plt.subplots(9,2,figsize = (20,15))
for i, feat in enumerate(cat_cols):
    sns.pointplot(x=feat, y = 'Creditability', data = data1, ax = ax[i//2,i%2])
    ax[i//2,i%2].grid(visible = True,linestyle = '--',color = 'wheat')
plt.suptitle("Relation between Creditability and cat_cols",fontsize =18, fontweight = 'bold')
plt.tight_layout()
plt.subplots_adjust(hspace = 2,wspace=0.5, top = 0.9)
plt.show()

# %% [markdown]
# From the above heatmap, we can see that there are four features with low correlation to Creditability: ['Foreign Worker', 'No of dependents', 'Guarantors', 'Duration in Current address']. Therefore, we will drop them.

# %%
remove_cols = ['Foreign Worker', 'No of dependents', 'Guarantors','Duration in Current address']
data = data1.copy()
data.drop(remove_cols,inplace= True, axis =1)

# %%
features = list(data.columns[1:])
num_features = len(features)
grid_size = math.ceil(num_features**0.5)
fig, axs = plt.subplots(grid_size,grid_size,figsize = (15,15))
axs = axs.flatten()
fig.suptitle("The histogram of the variables",fontsize = 16)
for i, feat in enumerate(features): 
    axs[i].hist(data[feat],bins = 10)
    axs[i].set_xlabel("Value", fontsize = 12)
    axs[i].set_ylabel("Frequency", fontsize = 12)
    axs[i].set_title(feat, fontsize = 14)
    axs[i].grid(True)
#Remove empty plots
for j in range(i+1,len(axs)):
    fig.delaxes(axs[j])
#Adjust the distances so that there is no overlap appear here
plt.tight_layout()
plt.subplots_adjust(left=0.05, top=0.93, bottom=0.05, wspace=0.5, hspace=0.8)
plt.show()

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### 4.1. Balancing the dataset

# %%
#Features and Label of Data
x = data.iloc[:,1:].values
y = data.iloc[:,0].values
#Standardlize 
scaler = StandardScaler()
scaler1 = RobustScaler()
scaler2 = MinMaxScaler()
x = scaler2.fit_transform(x)
#Balancing the dataset
ada = ADASYN(random_state=15)

# %% [markdown]
# ### 4.2. Hyper Tuning

# %%
# #GridSreach -> Hyper Tuning
# x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=2/3)
# x_train_res, y_train_res = ada.fit_resample(x_train,y_train)
# # use a full grid over all parameters
# param_grid = {"max_depth": [2,3,5, None],
#             "n_estimators":[50,100,200,300,400,500],
#             "max_features": [1, 3, 10],
#             "min_samples_split": [2, 3, 10],
#             "min_samples_leaf": [1, 3, 10],
#             "bootstrap": [True, False],
#             "criterion": ["gini", "entropy"]}
# forest_grid = GridSearchCV(estimator=RandomForestClassifier(random_state=0),
#                 param_grid = param_grid,   
#                 scoring="roc_auc",  #metrics
#                 cv = 5,              #cross-validation
#                 verbose= 1,
#                 refit = True,
#                 n_jobs = -1)          #number of core

# forest_grid.fit(x_train_res,y_train_res) #fit
# forest_grid_best = forest_grid.best_estimator_ #best estimator
# print("Best Model Parameter: ",forest_grid.best_params_)

# %% [markdown]
# ### 4.3. Training

# %%
#Create Stratified K-fold Object
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

skf = RepeatedStratifiedKFold(n_splits = 5 , random_state=1)

conf_matrices = []
precision_list = []
recall_list = []
f1_list = []
tprs = []
aucs = []
mean_fprs = np.linspace(0,1,100)
true_positive_prob = []
false_positive_prob = []

for train_index, test_index in tqdm(skf.split(x,y)):
    
    x_train, x_test = x[train_index],x[test_index]
    y_train, y_test = y[train_index],y[test_index]
    x_train,y_train = ada.fit_resample(x_train,y_train)
    
    def model_selection (name, model):
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        
        #Confusion Matrix 
        conf_matrix = confusion_matrix(y_test,y_pred)
        conf_matrices.append(conf_matrix)

        #Classification reports
        report = classification_report(y_test, y_pred, output_dict=True)
        precision_list.append(report['weighted avg']['precision'])
        recall_list.append(report['weighted avg']['recall'])
        f1_list.append(report['weighted avg']['f1-score'])

        # Probabilities for ROC Curve
        y_pred_proba = model.predict_proba(x_test)[:,1]

        # Compute ROC curve and area the curve
        fpr,tpr,thres = roc_curve(y_test,y_pred_proba)
        aucs.append(auc(fpr,tpr))
        tprs.append(np.interp(mean_fprs,fpr,tpr))
        tprs[-1][0] = 0.0

        # Collect probabilities for true positive prob and false positive prob
        true_positive_prob.extend(y_pred_proba[y_test == 1])
        false_positive_prob.extend(y_pred_proba[y_test == 0])
        
        #Mean of confusion Matrix
        mean_conf_matrix = np.mean(conf_matrices,axis =0)
        labels = ["Good","Bad"]
        plt.figure(figsize=(6,4))
        sns.heatmap(mean_conf_matrix, xticklabels=labels, yticklabels=labels,annot = True, fmt = 'g')
        plt.title("Confusion Matrix")
        plt.ylabel("True Class")
        plt.xlabel("Predicted Class")
        plt.tight_layout()
        plt.show()
        #Run classification metrics 
        print("Classification_report of this {} is:".format(name))
        print("Average Precision: {:.4f}".format(np.mean(precision_list)))
        print("Average Recall: {:.4f}".format(np.mean(recall_list)))
        print("Average F1-score: {:.4f}".format(np.mean(f1_list)))
# Out:
# 50it [00:00, 86.05it/s]

# %%
model_selection("RDF", RandomForestClassifier(n_estimators=500,criterion="gini",max_features=1, min_samples_leaf=1,min_samples_split=2,n_jobs=-1, max_depth = None, bootstrap = False))
# Out:
# Classification_report of this RDF is:
# Average Precision: 0.7351
# Average Recall: 0.7500
# Average F1-score: 0.7355

# %%
model_selection("KNN",KNeighborsClassifier(n_neighbors=3))
# Out:
# Classification_report of this KNN is:
# Average Precision: 0.7117
# Average Recall: 0.7025
# Average F1-score: 0.7008

# %%
model_selection("GaussianNB",GaussianNB())
# Out:
# Classification_report of this GaussianNB is:
# Average Precision: 0.7236
# Average Recall: 0.7000
# Average F1-score: 0.7029

# %%
model_selection('Gradient Boosting Classifier' ,GradientBoostingClassifier(max_depth=2, random_state=42))
# Out:
# Classification_report of this Gradient Boosting Classifier is:
# Average Precision: 0.7265
# Average Recall: 0.7100
# Average F1-score: 0.7115

# %%
model_selection('XGBoost',XGBClassifier(n_estimators=150, max_leaves=4))
# Out:
# Classification_report of this XGBoost is:
# Average Precision: 0.7275
# Average Recall: 0.7160
# Average F1-score: 0.7160

# %%
model_selection('Cat Boost',CatBoostClassifier())
# Out:
# Learning rate set to 0.01073
# 0:	learn: 0.6900384	total: 2.27ms	remaining: 2.27s
# 1:	learn: 0.6862540	total: 4.21ms	remaining: 2.1s
# 2:	learn: 0.6824681	total: 5.91ms	remaining: 1.97s
# 3:	learn: 0.6783455	total: 7.82ms	remaining: 1.95s
# 4:	learn: 0.6741393	total: 9.49ms	remaining: 1.89s
# 5:	learn: 0.6706773	total: 11.6ms	remaining: 1.92s
# 6:	learn: 0.6676807	total: 13.5ms	remaining: 1.92s
# 7:	learn: 0.6635253	total: 15.5ms	remaining: 1.92s
# 8:	learn: 0.6605253	total: 17.2ms	remaining: 1.89s
# 9:	learn: 0.6565882	total: 18.8ms	remaining: 1.86s
# 10:	learn: 0.6534792	total: 20.3ms	remaining: 1.82s
# 11:	learn: 0.6504942	total: 22ms	remaining: 1.81s
# 12:	learn: 0.6475414	total: 23.8ms	remaining: 1.81s
# 13:	learn: 0.6445471	total: 25.4ms	remaining: 1.79s
# 14:	learn: 0.6417352	total: 27ms	remaining: 1.77s
# 15:	learn: 0.6383796	total: 28.7ms	remaining: 1.77s
# 16:	learn: 0.6353550	total: 30.5ms	remaining: 1.76s
# 17:	learn: 0.6321528	total: 32.2ms	remaining: 1.75s
# 18:	learn: 0.6288529	total: 33.7ms	remaining: 1.74s
# 19:	learn: 0.6256630	total: 35.2ms	remaining: 1.73s
# 20:	learn: 0.6225639	total: 36.8ms	remaining: 1.71s
# 21:	learn: 0.6194135	total: 38.5ms	remaining: 1.71s
# 22:	learn: 0.6169881	total: 40.1ms	remaining: 1.7s
# 23:	learn: 0.6141589	total: 41.6ms	remaining: 1.69s
# 24:	learn: 0.6115709	total: 43.2ms	remaining: 1.68s
# 25:	learn: 0.6083542	total: 44.7ms	remaining: 1.67s
# 26:	learn: 0.6057107	total: 46.6ms	remaining: 1.68s
# 27:	learn: 0.6030262	total: 48.2ms	remaining: 1.67s
# 28:	learn: 0.6003325	total: 49.7ms	remaining: 1.66s
# 29:	learn: 0.5977924	total: 51.2ms	remaining: 1.66s
# 30:	learn: 0.5946793	total: 52.8ms	remaining: 1.65s
# 31:	learn: 0.5923294	total: 54.6ms	remaining: 1.65s
# 32:	learn: 0.5901539	total: 56.2ms	remaining: 1.65s
# 33:	learn: 0.5876598	total: 57.7ms	remaining: 1.64s
# 34:	learn: 0.5853682	total: 59.1ms	remaining: 1.63s
# 35:	learn: 0.5826578	total: 60.7ms	remaining: 1.63s
# 36:	learn: 0.5805929	total: 62.6ms	remaining: 1.63s
# 37:	learn: 0.5782781	total: 64.1ms	remaining: 1.62s
# 38:	learn: 0.5762701	total: 65.7ms	remaining: 1.62s
# 39:	learn: 0.5742904	total: 67.2ms	remaining: 1.61s
# 40:	learn: 0.5721219	total: 68.7ms	remaining: 1.61s
# 41:	learn: 0.5700916	total: 70.6ms	remaining: 1.61s
# 42:	learn: 0.5681075	total: 72.2ms	remaining: 1.6s
# 43:	learn: 0.5658243	total: 73.6ms	remaining: 1.6s
# 44:	learn: 0.5636051	total: 75.1ms	remaining: 1.59s
# 45:	learn: 0.5615716	total: 76.8ms	remaining: 1.59s
# 46:	learn: 0.5598153	total: 79ms	remaining: 1.6s
# 47:	learn: 0.5575024	total: 80.9ms	remaining: 1.6s
# 48:	learn: 0.5553189	total: 82.5ms	remaining: 1.6s
# 49:	learn: 0.5528714	total: 84.1ms	remaining: 1.6s
# 50:	learn: 0.5501312	total: 86ms	remaining: 1.6s
# 51:	learn: 0.5483590	total: 87.7ms	remaining: 1.6s
# 52:	learn: 0.5466241	total: 89.3ms	remaining: 1.59s
# 53:	learn: 0.5447478	total: 90.8ms	remaining: 1.59s
# 54:	learn: 0.5426989	total: 92.5ms	remaining: 1.59s
# 55:	learn: 0.5410071	total: 94.2ms	remaining: 1.59s
# 56:	learn: 0.5391117	total: 95.7ms	remaining: 1.58s
# 57:	learn: 0.5376921	total: 97.3ms	remaining: 1.58s
# 58:	learn: 0.5363612	total: 98.9ms	remaining: 1.58s
# 59:	learn: 0.5347565	total: 100ms	remaining: 1.57s
# 60:	learn: 0.5330647	total: 102ms	remaining: 1.58s
# 61:	learn: 0.5312276	total: 104ms	remaining: 1.57s
# 62:	learn: 0.5296452	total: 106ms	remaining: 1.57s
# 63:	learn: 0.5279772	total: 107ms	remaining: 1.57s
# 64:	learn: 0.5266334	total: 109ms	remaining: 1.57s
# 65:	learn: 0.5253230	total: 111ms	remaining: 1.57s
# 66:	learn: 0.5234437	total: 112ms	remaining: 1.56s
# 67:	learn: 0.5218046	total: 114ms	remaining: 1.56s
# 68:	learn: 0.5201718	total: 115ms	remaining: 1.56s
# 69:	learn: 0.5185440	total: 117ms	remaining: 1.55s
# 70:	learn: 0.5169408	total: 119ms	remaining: 1.55s
# 71:	learn: 0.5155599	total: 120ms	remaining: 1.55s
# 72:	learn: 0.5141076	total: 122ms	remaining: 1.55s
# 73:	learn: 0.5126382	total: 123ms	remaining: 1.54s
# 74:	learn: 0.5109277	total: 125ms	remaining: 1.54s
# 75:	learn: 0.5095046	total: 127ms	remaining: 1.55s
# 76:	learn: 0.5082186	total: 129ms	remaining: 1.54s
# 77:	learn: 0.5067609	total: 131ms	remaining: 1.54s
# 78:	learn: 0.5056015	total: 133ms	remaining: 1.55s
# 79:	learn: 0.5043396	total: 135ms	remaining: 1.55s
# 80:	learn: 0.5029240	total: 136ms	remaining: 1.55s
# 81:	learn: 0.5016291	total: 138ms	remaining: 1.54s
# 82:	learn: 0.5002516	total: 140ms	remaining: 1.54s
# 83:	learn: 0.4990981	total: 142ms	remaining: 1.54s
# 84:	learn: 0.4977761	total: 143ms	remaining: 1.54s
# 85:	learn: 0.4963263	total: 145ms	remaining: 1.54s
# 86:	learn: 0.4951744	total: 146ms	remaining: 1.53s
# 87:	learn: 0.4938019	total: 148ms	remaining: 1.53s
# 88:	learn: 0.4926155	total: 149ms	remaining: 1.53s
# 89:	learn: 0.4915014	total: 151ms	remaining: 1.53s
# 90:	learn: 0.4902540	total: 153ms	remaining: 1.52s
# 91:	learn: 0.4890134	total: 154ms	remaining: 1.52s
# 92:	learn: 0.4878204	total: 156ms	remaining: 1.52s
# 93:	learn: 0.4863346	total: 157ms	remaining: 1.52s
# 94:	learn: 0.4849087	total: 159ms	remaining: 1.51s
# 95:	learn: 0.4837051	total: 160ms	remaining: 1.51s
# 96:	learn: 0.4825458	total: 162ms	remaining: 1.51s
# 97:	learn: 0.4813879	total: 164ms	remaining: 1.51s
# 98:	learn: 0.4800246	total: 165ms	remaining: 1.5s
# 99:	learn: 0.4788394	total: 167ms	remaining: 1.5s
# 100:	learn: 0.4776607	total: 169ms	remaining: 1.5s
# 101:	learn: 0.4766562	total: 170ms	remaining: 1.5s
# 102:	learn: 0.4753539	total: 172ms	remaining: 1.5s
# 103:	learn: 0.4742537	total: 174ms	remaining: 1.5s
# 104:	learn: 0.4733213	total: 176ms	remaining: 1.5s
# 105:	learn: 0.4725019	total: 177ms	remaining: 1.49s
# 106:	learn: 0.4713420	total: 179ms	remaining: 1.49s
# 107:	learn: 0.4702243	total: 181ms	remaining: 1.49s
# 108:	learn: 0.4691083	total: 182ms	remaining: 1.49s
# 109:	learn: 0.4676950	total: 184ms	remaining: 1.49s
# 110:	learn: 0.4664028	total: 185ms	remaining: 1.48s
# 111:	learn: 0.4651356	total: 187ms	remaining: 1.48s
# 112:	learn: 0.4642762	total: 189ms	remaining: 1.49s
# 113:	learn: 0.4632907	total: 191ms	remaining: 1.48s
# 114:	learn: 0.4620879	total: 192ms	remaining: 1.48s
# 115:	learn: 0.4609963	total: 194ms	remaining: 1.48s
# 116:	learn: 0.4600388	total: 196ms	remaining: 1.48s
# 117:	learn: 0.4591369	total: 198ms	remaining: 1.48s
# 118:	learn: 0.4581635	total: 199ms	remaining: 1.47s
# 119:	learn: 0.4571281	total: 200ms	remaining: 1.47s
# 120:	learn: 0.4559813	total: 202ms	remaining: 1.47s
# 121:	learn: 0.4550176	total: 204ms	remaining: 1.47s
# 122:	learn: 0.4541878	total: 205ms	remaining: 1.46s
# 123:	learn: 0.4532718	total: 207ms	remaining: 1.46s
# 124:	learn: 0.4522538	total: 208ms	remaining: 1.46s
# 125:	learn: 0.4512107	total: 210ms	remaining: 1.46s
# 126:	learn: 0.4502027	total: 212ms	remaining: 1.46s
# 127:	learn: 0.4491099	total: 213ms	remaining: 1.45s
# 128:	learn: 0.4481052	total: 215ms	remaining: 1.45s
# 129:	learn: 0.4472859	total: 216ms	remaining: 1.45s
# 130:	learn: 0.4458854	total: 218ms	remaining: 1.45s
# 131:	learn: 0.4451122	total: 220ms	remaining: 1.44s
# 132:	learn: 0.4439722	total: 221ms	remaining: 1.44s
# 133:	learn: 0.4430743	total: 223ms	remaining: 1.44s
# 134:	learn: 0.4422162	total: 224ms	remaining: 1.44s
# 135:	learn: 0.4414330	total: 226ms	remaining: 1.43s
# 136:	learn: 0.4405099	total: 227ms	remaining: 1.43s
# 137:	learn: 0.4396487	total: 229ms	remaining: 1.43s
# 138:	learn: 0.4386530	total: 230ms	remaining: 1.43s
# 139:	learn: 0.4378910	total: 232ms	remaining: 1.43s
# 140:	learn: 0.4370794	total: 234ms	remaining: 1.42s
# 141:	learn: 0.4362716	total: 235ms	remaining: 1.42s
# 142:	learn: 0.4352336	total: 237ms	remaining: 1.42s
# 143:	learn: 0.4342423	total: 238ms	remaining: 1.42s
# 144:	learn: 0.4332703	total: 240ms	remaining: 1.41s
# 145:	learn: 0.4325876	total: 241ms	remaining: 1.41s
# 146:	learn: 0.4316165	total: 243ms	remaining: 1.41s
# 147:	learn: 0.4306022	total: 245ms	remaining: 1.41s
# 148:	learn: 0.4295710	total: 246ms	remaining: 1.41s
# 149:	learn: 0.4288133	total: 248ms	remaining: 1.4s
# 150:	learn: 0.4276144	total: 250ms	remaining: 1.4s
# 151:	learn: 0.4266955	total: 251ms	remaining: 1.4s
# 152:	learn: 0.4259804	total: 253ms	remaining: 1.4s
# 153:	learn: 0.4250694	total: 255ms	remaining: 1.4s
# 154:	learn: 0.4244397	total: 257ms	remaining: 1.4s
# 155:	learn: 0.4237486	total: 258ms	remaining: 1.4s
# 156:	learn: 0.4229168	total: 260ms	remaining: 1.4s
# 157:	learn: 0.4220883	total: 262ms	remaining: 1.4s
# 158:	learn: 0.4213166	total: 264ms	remaining: 1.39s
# 159:	learn: 0.4204797	total: 265ms	remaining: 1.39s
# 160:	learn: 0.4196712	total: 267ms	remaining: 1.39s
# 161:	learn: 0.4189165	total: 269ms	remaining: 1.39s
# 162:	learn: 0.4181572	total: 270ms	remaining: 1.39s
# 163:	learn: 0.4171152	total: 272ms	remaining: 1.39s
# 164:	learn: 0.4160135	total: 273ms	remaining: 1.38s
# 165:	learn: 0.4152147	total: 275ms	remaining: 1.38s
# 166:	learn: 0.4146228	total: 277ms	remaining: 1.38s
# 167:	learn: 0.4137533	total: 279ms	remaining: 1.38s
# 168:	learn: 0.4130755	total: 280ms	remaining: 1.38s
# 169:	learn: 0.4122761	total: 282ms	remaining: 1.38s
# 170:	learn: 0.4113682	total: 284ms	remaining: 1.38s
# 171:	learn: 0.4106316	total: 286ms	remaining: 1.37s
# 172:	learn: 0.4099289	total: 287ms	remaining: 1.37s
# 173:	learn: 0.4089981	total: 289ms	remaining: 1.37s
# 174:	learn: 0.4083583	total: 290ms	remaining: 1.37s
# 175:	learn: 0.4077034	total: 292ms	remaining: 1.37s
# 176:	learn: 0.4069219	total: 294ms	remaining: 1.37s
# 177:	learn: 0.4062650	total: 295ms	remaining: 1.36s
# 178:	learn: 0.4057826	total: 297ms	remaining: 1.36s
# 179:	learn: 0.4048820	total: 299ms	remaining: 1.36s
# 180:	learn: 0.4040898	total: 300ms	remaining: 1.36s
# 181:	learn: 0.4034486	total: 302ms	remaining: 1.36s
# 182:	learn: 0.4024603	total: 303ms	remaining: 1.35s
# 183:	learn: 0.4015795	total: 305ms	remaining: 1.35s
# 184:	learn: 0.4008333	total: 307ms	remaining: 1.35s
# 185:	learn: 0.4002218	total: 308ms	remaining: 1.35s
# 186:	learn: 0.3994326	total: 310ms	remaining: 1.35s
# 187:	learn: 0.3988892	total: 311ms	remaining: 1.34s
# 188:	learn: 0.3982999	total: 313ms	remaining: 1.34s
# 189:	learn: 0.3976036	total: 315ms	remaining: 1.34s
# 190:	learn: 0.3968382	total: 317ms	remaining: 1.34s
# 191:	learn: 0.3959738	total: 318ms	remaining: 1.34s
# 192:	learn: 0.3953374	total: 320ms	remaining: 1.34s
# 193:	learn: 0.3947259	total: 321ms	remaining: 1.33s
# 194:	learn: 0.3940119	total: 323ms	remaining: 1.33s
# 195:	learn: 0.3934338	total: 324ms	remaining: 1.33s
# 196:	learn: 0.3927883	total: 326ms	remaining: 1.33s
# 197:	learn: 0.3921230	total: 327ms	remaining: 1.33s
# 198:	learn: 0.3913832	total: 329ms	remaining: 1.32s
# 199:	learn: 0.3904310	total: 331ms	remaining: 1.32s
# 200:	learn: 0.3899329	total: 332ms	remaining: 1.32s
# 201:	learn: 0.3892859	total: 334ms	remaining: 1.32s
# 202:	learn: 0.3886716	total: 335ms	remaining: 1.32s
# 203:	learn: 0.3881167	total: 337ms	remaining: 1.31s
# 204:	learn: 0.3874586	total: 339ms	remaining: 1.31s
# 205:	learn: 0.3867589	total: 340ms	remaining: 1.31s
# 206:	learn: 0.3860271	total: 342ms	remaining: 1.31s
# 207:	learn: 0.3853940	total: 343ms	remaining: 1.31s
# 208:	learn: 0.3848789	total: 345ms	remaining: 1.31s
# 209:	learn: 0.3841888	total: 347ms	remaining: 1.3s
# 210:	learn: 0.3837442	total: 348ms	remaining: 1.3s
# 211:	learn: 0.3830321	total: 350ms	remaining: 1.3s
# 212:	learn: 0.3825558	total: 351ms	remaining: 1.3s
# 213:	learn: 0.3821080	total: 353ms	remaining: 1.3s
# 214:	learn: 0.3815627	total: 355ms	remaining: 1.29s
# 215:	learn: 0.3808226	total: 356ms	remaining: 1.29s
# 216:	learn: 0.3801942	total: 358ms	remaining: 1.29s
# 217:	learn: 0.3796598	total: 359ms	remaining: 1.29s
# 218:	learn: 0.3788249	total: 361ms	remaining: 1.29s
# 219:	learn: 0.3783424	total: 363ms	remaining: 1.28s
# 220:	learn: 0.3777969	total: 364ms	remaining: 1.28s
# 221:	learn: 0.3770671	total: 366ms	remaining: 1.28s
# 222:	learn: 0.3764869	total: 367ms	remaining: 1.28s
# 223:	learn: 0.3758313	total: 369ms	remaining: 1.28s
# 224:	learn: 0.3752077	total: 370ms	remaining: 1.28s
# 225:	learn: 0.3747011	total: 372ms	remaining: 1.27s
# 226:	learn: 0.3742641	total: 373ms	remaining: 1.27s
# 227:	learn: 0.3736626	total: 375ms	remaining: 1.27s
# 228:	learn: 0.3732266	total: 377ms	remaining: 1.27s
# 229:	learn: 0.3728427	total: 379ms	remaining: 1.27s
# 230:	learn: 0.3720452	total: 381ms	remaining: 1.27s
# 231:	learn: 0.3715876	total: 382ms	remaining: 1.26s
# 232:	learn: 0.3708081	total: 384ms	remaining: 1.26s
# 233:	learn: 0.3701200	total: 385ms	remaining: 1.26s
# 234:	learn: 0.3696365	total: 387ms	remaining: 1.26s
# 235:	learn: 0.3691044	total: 388ms	remaining: 1.26s
# 236:	learn: 0.3683569	total: 390ms	remaining: 1.25s
# 237:	learn: 0.3677087	total: 392ms	remaining: 1.25s
# 238:	learn: 0.3672940	total: 393ms	remaining: 1.25s
# 239:	learn: 0.3668242	total: 395ms	remaining: 1.25s
# 240:	learn: 0.3662244	total: 397ms	remaining: 1.25s
# 241:	learn: 0.3656211	total: 398ms	remaining: 1.25s
# 242:	learn: 0.3650177	total: 400ms	remaining: 1.25s
# 243:	learn: 0.3645456	total: 401ms	remaining: 1.24s
# 244:	learn: 0.3640954	total: 403ms	remaining: 1.24s
# 245:	learn: 0.3635288	total: 405ms	remaining: 1.24s
# 246:	learn: 0.3628551	total: 407ms	remaining: 1.24s
# 247:	learn: 0.3624022	total: 408ms	remaining: 1.24s
# 248:	learn: 0.3619782	total: 410ms	remaining: 1.24s
# 249:	learn: 0.3614002	total: 412ms	remaining: 1.24s
# 250:	learn: 0.3607877	total: 413ms	remaining: 1.23s
# 251:	learn: 0.3600988	total: 415ms	remaining: 1.23s
# 252:	learn: 0.3596691	total: 416ms	remaining: 1.23s
# 253:	learn: 0.3590073	total: 418ms	remaining: 1.23s
# 254:	learn: 0.3585005	total: 419ms	remaining: 1.23s
# 255:	learn: 0.3581116	total: 421ms	remaining: 1.22s
# 256:	learn: 0.3574664	total: 422ms	remaining: 1.22s
# 257:	learn: 0.3569663	total: 425ms	remaining: 1.22s
# 258:	learn: 0.3564843	total: 426ms	remaining: 1.22s
# 259:	learn: 0.3559937	total: 428ms	remaining: 1.22s
# 260:	learn: 0.3555559	total: 429ms	remaining: 1.22s
# 261:	learn: 0.3551942	total: 431ms	remaining: 1.21s
# 262:	learn: 0.3545970	total: 432ms	remaining: 1.21s
# 263:	learn: 0.3542256	total: 434ms	remaining: 1.21s
# 264:	learn: 0.3537770	total: 436ms	remaining: 1.21s
# 265:	learn: 0.3533050	total: 437ms	remaining: 1.21s
# 266:	learn: 0.3527725	total: 439ms	remaining: 1.2s
# 267:	learn: 0.3523665	total: 440ms	remaining: 1.2s
# 268:	learn: 0.3516444	total: 442ms	remaining: 1.2s
# 269:	learn: 0.3513101	total: 444ms	remaining: 1.2s
# 270:	learn: 0.3507785	total: 445ms	remaining: 1.2s
# 271:	learn: 0.3502238	total: 446ms	remaining: 1.19s
# 272:	learn: 0.3497383	total: 448ms	remaining: 1.19s
# 273:	learn: 0.3492648	total: 450ms	remaining: 1.19s
# 274:	learn: 0.3488821	total: 451ms	remaining: 1.19s
# 275:	learn: 0.3484180	total: 453ms	remaining: 1.19s
# 276:	learn: 0.3479755	total: 455ms	remaining: 1.19s
# 277:	learn: 0.3472495	total: 456ms	remaining: 1.19s
# 278:	learn: 0.3469304	total: 458ms	remaining: 1.18s
# 279:	learn: 0.3465835	total: 460ms	remaining: 1.18s
# 280:	learn: 0.3460123	total: 461ms	remaining: 1.18s
# 281:	learn: 0.3455067	total: 463ms	remaining: 1.18s
# 282:	learn: 0.3449899	total: 464ms	remaining: 1.18s
# 283:	learn: 0.3445456	total: 466ms	remaining: 1.17s
# 284:	learn: 0.3441325	total: 467ms	remaining: 1.17s
# 285:	learn: 0.3437706	total: 469ms	remaining: 1.17s
# 286:	learn: 0.3433047	total: 471ms	remaining: 1.17s
# 287:	learn: 0.3428337	total: 472ms	remaining: 1.17s
# 288:	learn: 0.3423592	total: 474ms	remaining: 1.17s
# 289:	learn: 0.3419214	total: 475ms	remaining: 1.16s
# 290:	learn: 0.3414860	total: 477ms	remaining: 1.16s
# 291:	learn: 0.3411091	total: 478ms	remaining: 1.16s
# 292:	learn: 0.3406529	total: 480ms	remaining: 1.16s
# 293:	learn: 0.3401331	total: 482ms	remaining: 1.16s
# 294:	learn: 0.3394384	total: 483ms	remaining: 1.15s
# 295:	learn: 0.3389150	total: 485ms	remaining: 1.15s
# 296:	learn: 0.3382445	total: 487ms	remaining: 1.15s
# 297:	learn: 0.3378697	total: 488ms	remaining: 1.15s
# 298:	learn: 0.3376452	total: 490ms	remaining: 1.15s
# 299:	learn: 0.3371946	total: 491ms	remaining: 1.15s
# 300:	learn: 0.3367068	total: 493ms	remaining: 1.14s
# 301:	learn: 0.3363393	total: 494ms	remaining: 1.14s
# 302:	learn: 0.3358730	total: 496ms	remaining: 1.14s
# 303:	learn: 0.3355427	total: 497ms	remaining: 1.14s
# 304:	learn: 0.3352166	total: 499ms	remaining: 1.14s
# 305:	learn: 0.3347004	total: 501ms	remaining: 1.14s
# 306:	learn: 0.3342913	total: 502ms	remaining: 1.13s
# 307:	learn: 0.3339521	total: 504ms	remaining: 1.13s
# 308:	learn: 0.3334831	total: 505ms	remaining: 1.13s
# 309:	learn: 0.3332068	total: 507ms	remaining: 1.13s
# 310:	learn: 0.3326957	total: 508ms	remaining: 1.13s
# 311:	learn: 0.3322338	total: 510ms	remaining: 1.12s
# 312:	learn: 0.3318855	total: 512ms	remaining: 1.12s
# 313:	learn: 0.3316180	total: 513ms	remaining: 1.12s
# 314:	learn: 0.3311647	total: 515ms	remaining: 1.12s
# 315:	learn: 0.3307111	total: 516ms	remaining: 1.12s
# 316:	learn: 0.3302378	total: 518ms	remaining: 1.11s
# 317:	learn: 0.3299791	total: 520ms	remaining: 1.11s
# 318:	learn: 0.3295653	total: 521ms	remaining: 1.11s
# 319:	learn: 0.3292072	total: 523ms	remaining: 1.11s
# 320:	learn: 0.3287199	total: 524ms	remaining: 1.11s
# 321:	learn: 0.3281532	total: 526ms	remaining: 1.11s
# 322:	learn: 0.3277649	total: 527ms	remaining: 1.1s
# 323:	learn: 0.3272572	total: 529ms	remaining: 1.1s
# 324:	learn: 0.3269110	total: 531ms	remaining: 1.1s
# 325:	learn: 0.3264807	total: 532ms	remaining: 1.1s
# 326:	learn: 0.3260381	total: 534ms	remaining: 1.1s
# 327:	learn: 0.3256526	total: 535ms	remaining: 1.1s
# 328:	learn: 0.3249623	total: 537ms	remaining: 1.09s
# 329:	learn: 0.3246195	total: 538ms	remaining: 1.09s
# 330:	learn: 0.3241127	total: 540ms	remaining: 1.09s
# 331:	learn: 0.3238268	total: 541ms	remaining: 1.09s
# 332:	learn: 0.3234186	total: 543ms	remaining: 1.09s
# 333:	learn: 0.3229762	total: 545ms	remaining: 1.09s
# 334:	learn: 0.3225504	total: 546ms	remaining: 1.08s
# 335:	learn: 0.3221491	total: 548ms	remaining: 1.08s
# 336:	learn: 0.3218636	total: 549ms	remaining: 1.08s
# 337:	learn: 0.3213614	total: 551ms	remaining: 1.08s
# 338:	learn: 0.3209673	total: 553ms	remaining: 1.08s
# 339:	learn: 0.3205811	total: 554ms	remaining: 1.08s
# 340:	learn: 0.3202025	total: 556ms	remaining: 1.07s
# 341:	learn: 0.3197772	total: 558ms	remaining: 1.07s
# 342:	learn: 0.3194030	total: 559ms	remaining: 1.07s
# 343:	learn: 0.3191502	total: 561ms	remaining: 1.07s
# 344:	learn: 0.3187453	total: 562ms	remaining: 1.07s
# 345:	learn: 0.3183405	total: 564ms	remaining: 1.06s
# 346:	learn: 0.3178214	total: 565ms	remaining: 1.06s
# 347:	learn: 0.3174181	total: 567ms	remaining: 1.06s
# 348:	learn: 0.3169118	total: 569ms	remaining: 1.06s
# 349:	learn: 0.3166113	total: 570ms	remaining: 1.06s
# 350:	learn: 0.3162123	total: 572ms	remaining: 1.06s
# 351:	learn: 0.3156606	total: 573ms	remaining: 1.05s
# 352:	learn: 0.3153847	total: 575ms	remaining: 1.05s
# 353:	learn: 0.3151074	total: 577ms	remaining: 1.05s
# 354:	learn: 0.3147311	total: 579ms	remaining: 1.05s
# 355:	learn: 0.3143678	total: 580ms	remaining: 1.05s
# 356:	learn: 0.3139694	total: 582ms	remaining: 1.05s
# 357:	learn: 0.3136110	total: 584ms	remaining: 1.05s
# 358:	learn: 0.3131747	total: 585ms	remaining: 1.04s
# 359:	learn: 0.3126636	total: 587ms	remaining: 1.04s
# 360:	learn: 0.3122819	total: 588ms	remaining: 1.04s
# 361:	learn: 0.3120675	total: 590ms	remaining: 1.04s
# 362:	learn: 0.3116769	total: 592ms	remaining: 1.04s
# 363:	learn: 0.3112447	total: 593ms	remaining: 1.04s
# 364:	learn: 0.3106459	total: 595ms	remaining: 1.03s
# 365:	learn: 0.3103601	total: 596ms	remaining: 1.03s
# 366:	learn: 0.3100385	total: 598ms	remaining: 1.03s
# 367:	learn: 0.3095296	total: 600ms	remaining: 1.03s
# 368:	learn: 0.3091878	total: 601ms	remaining: 1.03s
# 369:	learn: 0.3088685	total: 603ms	remaining: 1.03s
# 370:	learn: 0.3085785	total: 605ms	remaining: 1.02s
# 371:	learn: 0.3082159	total: 607ms	remaining: 1.02s
# 372:	learn: 0.3078989	total: 608ms	remaining: 1.02s
# 373:	learn: 0.3074205	total: 610ms	remaining: 1.02s
# 374:	learn: 0.3070289	total: 611ms	remaining: 1.02s
# 375:	learn: 0.3067188	total: 613ms	remaining: 1.02s
# 376:	learn: 0.3061847	total: 615ms	remaining: 1.01s
# 377:	learn: 0.3058239	total: 616ms	remaining: 1.01s
# 378:	learn: 0.3054798	total: 618ms	remaining: 1.01s
# 379:	learn: 0.3050914	total: 619ms	remaining: 1.01s
# 380:	learn: 0.3047304	total: 621ms	remaining: 1.01s
# 381:	learn: 0.3044439	total: 623ms	remaining: 1.01s
# 382:	learn: 0.3041278	total: 624ms	remaining: 1s
# 383:	learn: 0.3037620	total: 626ms	remaining: 1s
# 384:	learn: 0.3035001	total: 627ms	remaining: 1s
# 385:	learn: 0.3031650	total: 629ms	remaining: 1s
# 386:	learn: 0.3028858	total: 630ms	remaining: 999ms
# 387:	learn: 0.3024344	total: 632ms	remaining: 997ms
# 388:	learn: 0.3021820	total: 634ms	remaining: 995ms
# 389:	learn: 0.3019221	total: 635ms	remaining: 994ms
# 390:	learn: 0.3014827	total: 637ms	remaining: 992ms
# 391:	learn: 0.3012300	total: 639ms	remaining: 991ms
# 392:	learn: 0.3009401	total: 640ms	remaining: 989ms
# 393:	learn: 0.3006743	total: 642ms	remaining: 987ms
# 394:	learn: 0.3001965	total: 643ms	remaining: 985ms
# 395:	learn: 0.2998032	total: 645ms	remaining: 984ms
# 396:	learn: 0.2993967	total: 647ms	remaining: 982ms
# 397:	learn: 0.2992484	total: 648ms	remaining: 980ms
# 398:	learn: 0.2988541	total: 650ms	remaining: 979ms
# 399:	learn: 0.2984729	total: 651ms	remaining: 977ms
# 400:	learn: 0.2981797	total: 653ms	remaining: 976ms
# 401:	learn: 0.2978450	total: 655ms	remaining: 974ms
# 402:	learn: 0.2975305	total: 656ms	remaining: 972ms
# 403:	learn: 0.2971730	total: 658ms	remaining: 970ms
# 404:	learn: 0.2968592	total: 659ms	remaining: 969ms
# 405:	learn: 0.2965426	total: 661ms	remaining: 967ms
# 406:	learn: 0.2960809	total: 663ms	remaining: 966ms
# 407:	learn: 0.2957861	total: 664ms	remaining: 964ms
# 408:	learn: 0.2953780	total: 666ms	remaining: 962ms
# 409:	learn: 0.2949999	total: 668ms	remaining: 961ms
# 410:	learn: 0.2944885	total: 669ms	remaining: 959ms
# 411:	learn: 0.2941190	total: 671ms	remaining: 957ms
# 412:	learn: 0.2937261	total: 672ms	remaining: 956ms
# 413:	learn: 0.2934207	total: 674ms	remaining: 954ms
# 414:	learn: 0.2931136	total: 675ms	remaining: 952ms
# 415:	learn: 0.2928931	total: 677ms	remaining: 950ms
# 416:	learn: 0.2926402	total: 679ms	remaining: 949ms
# 417:	learn: 0.2922771	total: 680ms	remaining: 947ms
# 418:	learn: 0.2919009	total: 682ms	remaining: 945ms
# 419:	learn: 0.2915323	total: 683ms	remaining: 944ms
# 420:	learn: 0.2913054	total: 685ms	remaining: 942ms
# 421:	learn: 0.2909114	total: 687ms	remaining: 941ms
# 422:	learn: 0.2904453	total: 688ms	remaining: 939ms
# 423:	learn: 0.2901317	total: 690ms	remaining: 937ms
# 424:	learn: 0.2898654	total: 691ms	remaining: 935ms
# 425:	learn: 0.2894570	total: 693ms	remaining: 934ms
# 426:	learn: 0.2890447	total: 695ms	remaining: 932ms
# 427:	learn: 0.2886209	total: 697ms	remaining: 931ms
# 428:	learn: 0.2879857	total: 698ms	remaining: 930ms
# 429:	learn: 0.2876196	total: 700ms	remaining: 928ms
# 430:	learn: 0.2872278	total: 702ms	remaining: 927ms
# 431:	learn: 0.2869522	total: 704ms	remaining: 925ms
# 432:	learn: 0.2866714	total: 705ms	remaining: 923ms
# 433:	learn: 0.2861938	total: 707ms	remaining: 922ms
# 434:	learn: 0.2858805	total: 709ms	remaining: 920ms
# 435:	learn: 0.2855832	total: 710ms	remaining: 919ms
# 436:	learn: 0.2852664	total: 712ms	remaining: 917ms
# 437:	learn: 0.2848826	total: 714ms	remaining: 916ms
# 438:	learn: 0.2844889	total: 715ms	remaining: 914ms
# 439:	learn: 0.2842459	total: 717ms	remaining: 913ms
# 440:	learn: 0.2838169	total: 719ms	remaining: 911ms
# 441:	learn: 0.2835597	total: 721ms	remaining: 910ms
# 442:	learn: 0.2833072	total: 722ms	remaining: 908ms
# 443:	learn: 0.2830451	total: 724ms	remaining: 907ms
# 444:	learn: 0.2828031	total: 726ms	remaining: 905ms
# 445:	learn: 0.2823677	total: 727ms	remaining: 904ms
# 446:	learn: 0.2820485	total: 729ms	remaining: 902ms
# 447:	learn: 0.2817699	total: 730ms	remaining: 900ms
# 448:	learn: 0.2812619	total: 732ms	remaining: 899ms
# 449:	learn: 0.2809362	total: 734ms	remaining: 897ms
# 450:	learn: 0.2805022	total: 735ms	remaining: 895ms
# 451:	learn: 0.2802919	total: 737ms	remaining: 893ms
# 452:	learn: 0.2797723	total: 738ms	remaining: 892ms
# 453:	learn: 0.2795008	total: 740ms	remaining: 890ms
# 454:	learn: 0.2792859	total: 742ms	remaining: 888ms
# 455:	learn: 0.2788637	total: 743ms	remaining: 887ms
# 456:	learn: 0.2785352	total: 745ms	remaining: 885ms
# 457:	learn: 0.2781955	total: 746ms	remaining: 883ms
# 458:	learn: 0.2776820	total: 748ms	remaining: 882ms
# 459:	learn: 0.2773709	total: 750ms	remaining: 880ms
# 460:	learn: 0.2770795	total: 751ms	remaining: 878ms
# 461:	learn: 0.2768688	total: 753ms	remaining: 876ms
# 462:	learn: 0.2765729	total: 754ms	remaining: 875ms
# 463:	learn: 0.2762256	total: 756ms	remaining: 874ms
# 464:	learn: 0.2759609	total: 758ms	remaining: 872ms
# 465:	learn: 0.2756148	total: 759ms	remaining: 870ms
# 466:	learn: 0.2753209	total: 761ms	remaining: 868ms
# 467:	learn: 0.2750295	total: 762ms	remaining: 867ms
# 468:	learn: 0.2745526	total: 764ms	remaining: 865ms
# 469:	learn: 0.2743169	total: 766ms	remaining: 863ms
# 470:	learn: 0.2738816	total: 767ms	remaining: 862ms
# 471:	learn: 0.2735576	total: 769ms	remaining: 861ms
# 472:	learn: 0.2731672	total: 772ms	remaining: 860ms
# 473:	learn: 0.2730175	total: 773ms	remaining: 858ms
# 474:	learn: 0.2725366	total: 775ms	remaining: 856ms
# 475:	learn: 0.2722968	total: 777ms	remaining: 855ms
# 476:	learn: 0.2720576	total: 778ms	remaining: 853ms
# 477:	learn: 0.2716931	total: 780ms	remaining: 852ms
# 478:	learn: 0.2714575	total: 782ms	remaining: 850ms
# 479:	learn: 0.2711646	total: 783ms	remaining: 848ms
# 480:	learn: 0.2708294	total: 785ms	remaining: 847ms
# 481:	learn: 0.2705669	total: 787ms	remaining: 846ms
# 482:	learn: 0.2701813	total: 788ms	remaining: 844ms
# 483:	learn: 0.2699423	total: 790ms	remaining: 842ms
# 484:	learn: 0.2696713	total: 791ms	remaining: 840ms
# 485:	learn: 0.2691799	total: 793ms	remaining: 839ms
# 486:	learn: 0.2688196	total: 795ms	remaining: 837ms
# 487:	learn: 0.2684318	total: 796ms	remaining: 835ms
# 488:	learn: 0.2680833	total: 798ms	remaining: 834ms
# 489:	learn: 0.2677484	total: 800ms	remaining: 832ms
# 490:	learn: 0.2675159	total: 801ms	remaining: 830ms
# 491:	learn: 0.2671410	total: 803ms	remaining: 829ms
# 492:	learn: 0.2667927	total: 804ms	remaining: 827ms
# 493:	learn: 0.2665223	total: 806ms	remaining: 825ms
# 494:	learn: 0.2661711	total: 807ms	remaining: 824ms
# 495:	learn: 0.2658641	total: 809ms	remaining: 822ms
# 496:	learn: 0.2655472	total: 811ms	remaining: 820ms
# 497:	learn: 0.2652737	total: 812ms	remaining: 819ms
# 498:	learn: 0.2650094	total: 814ms	remaining: 817ms
# 499:	learn: 0.2646633	total: 815ms	remaining: 815ms
# 500:	learn: 0.2642996	total: 817ms	remaining: 814ms
# 501:	learn: 0.2639350	total: 818ms	remaining: 812ms
# 502:	learn: 0.2636203	total: 820ms	remaining: 810ms
# 503:	learn: 0.2631883	total: 822ms	remaining: 808ms
# 504:	learn: 0.2628965	total: 823ms	remaining: 807ms
# 505:	learn: 0.2625973	total: 824ms	remaining: 805ms
# 506:	learn: 0.2624046	total: 826ms	remaining: 803ms
# 507:	learn: 0.2620392	total: 828ms	remaining: 802ms
# 508:	learn: 0.2618336	total: 829ms	remaining: 800ms
# 509:	learn: 0.2616948	total: 831ms	remaining: 798ms
# 510:	learn: 0.2614162	total: 833ms	remaining: 797ms
# 511:	learn: 0.2611773	total: 834ms	remaining: 795ms
# 512:	learn: 0.2607877	total: 836ms	remaining: 793ms
# 513:	learn: 0.2604197	total: 837ms	remaining: 792ms
# 514:	learn: 0.2601706	total: 839ms	remaining: 790ms
# 515:	learn: 0.2598466	total: 840ms	remaining: 788ms
# 516:	learn: 0.2595075	total: 842ms	remaining: 787ms
# 517:	learn: 0.2592931	total: 844ms	remaining: 785ms
# 518:	learn: 0.2590182	total: 845ms	remaining: 784ms
# 519:	learn: 0.2588396	total: 847ms	remaining: 782ms
# 520:	learn: 0.2586109	total: 849ms	remaining: 780ms
# 521:	learn: 0.2582633	total: 850ms	remaining: 779ms
# 522:	learn: 0.2580027	total: 852ms	remaining: 777ms
# 523:	learn: 0.2577779	total: 854ms	remaining: 776ms
# 524:	learn: 0.2574612	total: 855ms	remaining: 774ms
# 525:	learn: 0.2571515	total: 857ms	remaining: 772ms
# 526:	learn: 0.2570117	total: 859ms	remaining: 771ms
# 527:	learn: 0.2567989	total: 861ms	remaining: 769ms
# 528:	learn: 0.2564653	total: 862ms	remaining: 768ms
# 529:	learn: 0.2562934	total: 864ms	remaining: 766ms
# 530:	learn: 0.2560476	total: 865ms	remaining: 764ms
# 531:	learn: 0.2558663	total: 867ms	remaining: 763ms
# 532:	learn: 0.2554585	total: 868ms	remaining: 761ms
# 533:	learn: 0.2551560	total: 870ms	remaining: 759ms
# 534:	learn: 0.2546859	total: 871ms	remaining: 757ms
# 535:	learn: 0.2543677	total: 873ms	remaining: 756ms
# 536:	learn: 0.2541491	total: 875ms	remaining: 754ms
# 537:	learn: 0.2537514	total: 876ms	remaining: 753ms
# 538:	learn: 0.2535072	total: 878ms	remaining: 751ms
# 539:	learn: 0.2532966	total: 879ms	remaining: 749ms
# 540:	learn: 0.2529637	total: 881ms	remaining: 747ms
# 541:	learn: 0.2527119	total: 883ms	remaining: 746ms
# 542:	learn: 0.2524607	total: 884ms	remaining: 744ms
# 543:	learn: 0.2520476	total: 886ms	remaining: 742ms
# 544:	learn: 0.2518319	total: 887ms	remaining: 741ms
# 545:	learn: 0.2514439	total: 889ms	remaining: 739ms
# 546:	learn: 0.2511176	total: 890ms	remaining: 737ms
# 547:	learn: 0.2507829	total: 892ms	remaining: 736ms
# 548:	learn: 0.2505650	total: 894ms	remaining: 734ms
# 549:	learn: 0.2502405	total: 895ms	remaining: 733ms
# 550:	learn: 0.2499583	total: 897ms	remaining: 731ms
# 551:	learn: 0.2496650	total: 899ms	remaining: 729ms
# 552:	learn: 0.2495192	total: 900ms	remaining: 728ms
# 553:	learn: 0.2492186	total: 902ms	remaining: 726ms
# 554:	learn: 0.2489859	total: 903ms	remaining: 724ms
# 555:	learn: 0.2486853	total: 905ms	remaining: 722ms
# 556:	learn: 0.2484392	total: 907ms	remaining: 721ms
# 557:	learn: 0.2480563	total: 908ms	remaining: 719ms
# 558:	learn: 0.2478963	total: 910ms	remaining: 718ms
# 559:	learn: 0.2477297	total: 911ms	remaining: 716ms
# 560:	learn: 0.2473773	total: 913ms	remaining: 714ms
# 561:	learn: 0.2472133	total: 915ms	remaining: 713ms
# 562:	learn: 0.2468220	total: 916ms	remaining: 711ms
# 563:	learn: 0.2466438	total: 918ms	remaining: 709ms
# 564:	learn: 0.2464136	total: 919ms	remaining: 708ms
# 565:	learn: 0.2461576	total: 921ms	remaining: 706ms
# 566:	learn: 0.2458145	total: 923ms	remaining: 705ms
# 567:	learn: 0.2453889	total: 924ms	remaining: 703ms
# 568:	learn: 0.2452054	total: 926ms	remaining: 701ms
# 569:	learn: 0.2449377	total: 927ms	remaining: 699ms
# 570:	learn: 0.2446061	total: 929ms	remaining: 698ms
# 571:	learn: 0.2443711	total: 930ms	remaining: 696ms
# 572:	learn: 0.2441243	total: 932ms	remaining: 695ms
# 573:	learn: 0.2439223	total: 933ms	remaining: 693ms
# 574:	learn: 0.2435536	total: 935ms	remaining: 691ms
# 575:	learn: 0.2431916	total: 937ms	remaining: 690ms
# 576:	learn: 0.2429008	total: 939ms	remaining: 688ms
# 577:	learn: 0.2426748	total: 940ms	remaining: 686ms
# 578:	learn: 0.2423790	total: 942ms	remaining: 685ms
# 579:	learn: 0.2421631	total: 943ms	remaining: 683ms
# 580:	learn: 0.2420050	total: 945ms	remaining: 681ms
# 581:	learn: 0.2416595	total: 947ms	remaining: 680ms
# 582:	learn: 0.2414125	total: 948ms	remaining: 678ms
# 583:	learn: 0.2409300	total: 950ms	remaining: 676ms
# 584:	learn: 0.2407099	total: 951ms	remaining: 675ms
# 585:	learn: 0.2403998	total: 953ms	remaining: 673ms
# 586:	learn: 0.2401516	total: 955ms	remaining: 672ms
# 587:	learn: 0.2399386	total: 956ms	remaining: 670ms
# 588:	learn: 0.2397397	total: 958ms	remaining: 668ms
# 589:	learn: 0.2394821	total: 959ms	remaining: 667ms
# 590:	learn: 0.2391818	total: 961ms	remaining: 665ms
# 591:	learn: 0.2389080	total: 963ms	remaining: 663ms
# 592:	learn: 0.2386308	total: 964ms	remaining: 662ms
# 593:	learn: 0.2384264	total: 966ms	remaining: 660ms
# 594:	learn: 0.2382007	total: 969ms	remaining: 659ms
# 595:	learn: 0.2380019	total: 971ms	remaining: 658ms
# 596:	learn: 0.2376387	total: 972ms	remaining: 656ms
# 597:	learn: 0.2374065	total: 974ms	remaining: 655ms
# 598:	learn: 0.2370517	total: 976ms	remaining: 653ms
# 599:	learn: 0.2368537	total: 977ms	remaining: 652ms
# 600:	learn: 0.2366023	total: 979ms	remaining: 650ms
# 601:	learn: 0.2361818	total: 981ms	remaining: 648ms
# 602:	learn: 0.2358496	total: 982ms	remaining: 647ms
# 603:	learn: 0.2356057	total: 984ms	remaining: 645ms
# 604:	learn: 0.2352409	total: 986ms	remaining: 644ms
# 605:	learn: 0.2350870	total: 987ms	remaining: 642ms
# 606:	learn: 0.2349013	total: 989ms	remaining: 640ms
# 607:	learn: 0.2346442	total: 990ms	remaining: 639ms
# 608:	learn: 0.2343913	total: 992ms	remaining: 637ms
# 609:	learn: 0.2341128	total: 994ms	remaining: 636ms
# 610:	learn: 0.2338728	total: 996ms	remaining: 634ms
# 611:	learn: 0.2336044	total: 997ms	remaining: 632ms
# 612:	learn: 0.2333513	total: 999ms	remaining: 631ms
# 613:	learn: 0.2331396	total: 1s	remaining: 629ms
# 614:	learn: 0.2328659	total: 1s	remaining: 628ms
# 615:	learn: 0.2327233	total: 1s	remaining: 626ms
# 616:	learn: 0.2325025	total: 1s	remaining: 624ms
# 617:	learn: 0.2323328	total: 1.01s	remaining: 622ms
# 618:	learn: 0.2320552	total: 1.01s	remaining: 621ms
# 619:	learn: 0.2317681	total: 1.01s	remaining: 619ms
# 620:	learn: 0.2315343	total: 1.01s	remaining: 618ms
# 621:	learn: 0.2313288	total: 1.01s	remaining: 616ms
# 622:	learn: 0.2311080	total: 1.01s	remaining: 615ms
# 623:	learn: 0.2308660	total: 1.02s	remaining: 613ms
# 624:	learn: 0.2305911	total: 1.02s	remaining: 611ms
# 625:	learn: 0.2302858	total: 1.02s	remaining: 610ms
# 626:	learn: 0.2300152	total: 1.02s	remaining: 608ms
# 627:	learn: 0.2298189	total: 1.02s	remaining: 606ms
# 628:	learn: 0.2295077	total: 1.02s	remaining: 605ms
# 629:	learn: 0.2292046	total: 1.03s	remaining: 603ms
# 630:	learn: 0.2289249	total: 1.03s	remaining: 601ms
# 631:	learn: 0.2287124	total: 1.03s	remaining: 600ms
# 632:	learn: 0.2284780	total: 1.03s	remaining: 598ms
# 633:	learn: 0.2281137	total: 1.03s	remaining: 596ms
# 634:	learn: 0.2279055	total: 1.03s	remaining: 595ms
# 635:	learn: 0.2277425	total: 1.04s	remaining: 593ms
# 636:	learn: 0.2275359	total: 1.04s	remaining: 591ms
# 637:	learn: 0.2272173	total: 1.04s	remaining: 590ms
# 638:	learn: 0.2269389	total: 1.04s	remaining: 588ms
# 639:	learn: 0.2266778	total: 1.04s	remaining: 586ms
# 640:	learn: 0.2263754	total: 1.04s	remaining: 585ms
# 641:	learn: 0.2261201	total: 1.04s	remaining: 583ms
# 642:	learn: 0.2259017	total: 1.05s	remaining: 581ms
# 643:	learn: 0.2256834	total: 1.05s	remaining: 580ms
# 644:	learn: 0.2254838	total: 1.05s	remaining: 578ms
# 645:	learn: 0.2253174	total: 1.05s	remaining: 576ms
# 646:	learn: 0.2251067	total: 1.05s	remaining: 575ms
# 647:	learn: 0.2248011	total: 1.05s	remaining: 573ms
# 648:	learn: 0.2245296	total: 1.06s	remaining: 572ms
# 649:	learn: 0.2242767	total: 1.06s	remaining: 570ms
# 650:	learn: 0.2240225	total: 1.06s	remaining: 568ms
# 651:	learn: 0.2237658	total: 1.06s	remaining: 567ms
# 652:	learn: 0.2234500	total: 1.06s	remaining: 565ms
# 653:	learn: 0.2232760	total: 1.06s	remaining: 564ms
# 654:	learn: 0.2230225	total: 1.07s	remaining: 562ms
# 655:	learn: 0.2227250	total: 1.07s	remaining: 560ms
# 656:	learn: 0.2224074	total: 1.07s	remaining: 559ms
# 657:	learn: 0.2221047	total: 1.07s	remaining: 557ms
# 658:	learn: 0.2219425	total: 1.07s	remaining: 556ms
# 659:	learn: 0.2217137	total: 1.07s	remaining: 554ms
# 660:	learn: 0.2214471	total: 1.08s	remaining: 552ms
# 661:	learn: 0.2212108	total: 1.08s	remaining: 551ms
# 662:	learn: 0.2210049	total: 1.08s	remaining: 549ms
# 663:	learn: 0.2206648	total: 1.08s	remaining: 548ms
# 664:	learn: 0.2204877	total: 1.08s	remaining: 546ms
# 665:	learn: 0.2203072	total: 1.08s	remaining: 545ms
# 666:	learn: 0.2200462	total: 1.09s	remaining: 543ms
# 667:	learn: 0.2198444	total: 1.09s	remaining: 541ms
# 668:	learn: 0.2196429	total: 1.09s	remaining: 540ms
# 669:	learn: 0.2194159	total: 1.09s	remaining: 538ms
# 670:	learn: 0.2191987	total: 1.09s	remaining: 536ms
# 671:	learn: 0.2188922	total: 1.09s	remaining: 535ms
# 672:	learn: 0.2187011	total: 1.1s	remaining: 533ms
# 673:	learn: 0.2184902	total: 1.1s	remaining: 532ms
# 674:	learn: 0.2182436	total: 1.1s	remaining: 530ms
# 675:	learn: 0.2180496	total: 1.1s	remaining: 528ms
# 676:	learn: 0.2178857	total: 1.1s	remaining: 527ms
# 677:	learn: 0.2175356	total: 1.1s	remaining: 525ms
# 678:	learn: 0.2173547	total: 1.11s	remaining: 524ms
# 679:	learn: 0.2171547	total: 1.11s	remaining: 522ms
# 680:	learn: 0.2169971	total: 1.11s	remaining: 520ms
# 681:	learn: 0.2166171	total: 1.11s	remaining: 519ms
# 682:	learn: 0.2163394	total: 1.11s	remaining: 517ms
# 683:	learn: 0.2161782	total: 1.11s	remaining: 515ms
# 684:	learn: 0.2160088	total: 1.12s	remaining: 514ms
# 685:	learn: 0.2158441	total: 1.12s	remaining: 512ms
# 686:	learn: 0.2155114	total: 1.12s	remaining: 511ms
# 687:	learn: 0.2152936	total: 1.12s	remaining: 509ms
# 688:	learn: 0.2150634	total: 1.12s	remaining: 507ms
# 689:	learn: 0.2148451	total: 1.13s	remaining: 506ms
# 690:	learn: 0.2146527	total: 1.13s	remaining: 504ms
# 691:	learn: 0.2144840	total: 1.13s	remaining: 503ms
# 692:	learn: 0.2143224	total: 1.13s	remaining: 501ms
# 693:	learn: 0.2140668	total: 1.13s	remaining: 499ms
# 694:	learn: 0.2138062	total: 1.13s	remaining: 498ms
# 695:	learn: 0.2135693	total: 1.14s	remaining: 496ms
# 696:	learn: 0.2132498	total: 1.14s	remaining: 494ms
# 697:	learn: 0.2130667	total: 1.14s	remaining: 493ms
# 698:	learn: 0.2129006	total: 1.14s	remaining: 491ms
# 699:	learn: 0.2126981	total: 1.14s	remaining: 489ms
# 700:	learn: 0.2124867	total: 1.14s	remaining: 488ms
# 701:	learn: 0.2122406	total: 1.15s	remaining: 486ms
# 702:	learn: 0.2120280	total: 1.15s	remaining: 485ms
# 703:	learn: 0.2118107	total: 1.15s	remaining: 483ms
# 704:	learn: 0.2116592	total: 1.15s	remaining: 482ms
# 705:	learn: 0.2114665	total: 1.15s	remaining: 480ms
# 706:	learn: 0.2111796	total: 1.15s	remaining: 478ms
# 707:	learn: 0.2109987	total: 1.16s	remaining: 477ms
# 708:	learn: 0.2108736	total: 1.16s	remaining: 475ms
# 709:	learn: 0.2106225	total: 1.16s	remaining: 473ms
# 710:	learn: 0.2104340	total: 1.16s	remaining: 472ms
# 711:	learn: 0.2102162	total: 1.16s	remaining: 470ms
# 712:	learn: 0.2099985	total: 1.16s	remaining: 469ms
# 713:	learn: 0.2097423	total: 1.17s	remaining: 467ms
# 714:	learn: 0.2095173	total: 1.17s	remaining: 466ms
# 715:	learn: 0.2092894	total: 1.17s	remaining: 464ms
# 716:	learn: 0.2090493	total: 1.17s	remaining: 462ms
# 717:	learn: 0.2088791	total: 1.17s	remaining: 461ms
# 718:	learn: 0.2086467	total: 1.17s	remaining: 459ms
# 719:	learn: 0.2084510	total: 1.18s	remaining: 458ms
# 720:	learn: 0.2082278	total: 1.18s	remaining: 456ms
# 721:	learn: 0.2080846	total: 1.18s	remaining: 454ms
# 722:	learn: 0.2077969	total: 1.18s	remaining: 453ms
# 723:	learn: 0.2074975	total: 1.18s	remaining: 452ms
# 724:	learn: 0.2072326	total: 1.19s	remaining: 450ms
# 725:	learn: 0.2070103	total: 1.19s	remaining: 448ms
# 726:	learn: 0.2067409	total: 1.19s	remaining: 447ms
# 727:	learn: 0.2064889	total: 1.19s	remaining: 445ms
# 728:	learn: 0.2062652	total: 1.19s	remaining: 443ms
# 729:	learn: 0.2060662	total: 1.19s	remaining: 442ms
# 730:	learn: 0.2058608	total: 1.2s	remaining: 440ms
# 731:	learn: 0.2057442	total: 1.2s	remaining: 439ms
# 732:	learn: 0.2055720	total: 1.2s	remaining: 437ms
# 733:	learn: 0.2053501	total: 1.2s	remaining: 436ms
# 734:	learn: 0.2051754	total: 1.2s	remaining: 434ms
# 735:	learn: 0.2050021	total: 1.21s	remaining: 433ms
# 736:	learn: 0.2047638	total: 1.21s	remaining: 431ms
# 737:	learn: 0.2043878	total: 1.21s	remaining: 429ms
# 738:	learn: 0.2042000	total: 1.21s	remaining: 428ms
# 739:	learn: 0.2040651	total: 1.21s	remaining: 426ms
# 740:	learn: 0.2038207	total: 1.21s	remaining: 425ms
# 741:	learn: 0.2036183	total: 1.22s	remaining: 423ms
# 742:	learn: 0.2034440	total: 1.22s	remaining: 421ms
# 743:	learn: 0.2032509	total: 1.22s	remaining: 420ms
# 744:	learn: 0.2029792	total: 1.22s	remaining: 418ms
# 745:	learn: 0.2026981	total: 1.22s	remaining: 417ms
# 746:	learn: 0.2025734	total: 1.23s	remaining: 415ms
# 747:	learn: 0.2023702	total: 1.23s	remaining: 413ms
# 748:	learn: 0.2021483	total: 1.23s	remaining: 412ms
# 749:	learn: 0.2018266	total: 1.23s	remaining: 410ms
# 750:	learn: 0.2015763	total: 1.23s	remaining: 408ms
# 751:	learn: 0.2012866	total: 1.23s	remaining: 407ms
# 752:	learn: 0.2010607	total: 1.24s	remaining: 405ms
# 753:	learn: 0.2009262	total: 1.24s	remaining: 404ms
# 754:	learn: 0.2006566	total: 1.24s	remaining: 402ms
# 755:	learn: 0.2004825	total: 1.24s	remaining: 400ms
# 756:	learn: 0.2003267	total: 1.24s	remaining: 399ms
# 757:	learn: 0.2000827	total: 1.24s	remaining: 397ms
# 758:	learn: 0.1999318	total: 1.25s	remaining: 395ms
# 759:	learn: 0.1997442	total: 1.25s	remaining: 394ms
# 760:	learn: 0.1996256	total: 1.25s	remaining: 392ms
# 761:	learn: 0.1994047	total: 1.25s	remaining: 390ms
# 762:	learn: 0.1990855	total: 1.25s	remaining: 389ms
# 763:	learn: 0.1988681	total: 1.25s	remaining: 387ms
# 764:	learn: 0.1987057	total: 1.25s	remaining: 386ms
# 765:	learn: 0.1985285	total: 1.26s	remaining: 384ms
# 766:	learn: 0.1983060	total: 1.26s	remaining: 382ms
# 767:	learn: 0.1981666	total: 1.26s	remaining: 381ms
# 768:	learn: 0.1979595	total: 1.26s	remaining: 379ms
# 769:	learn: 0.1978079	total: 1.26s	remaining: 377ms
# 770:	learn: 0.1975725	total: 1.26s	remaining: 376ms
# 771:	learn: 0.1973716	total: 1.27s	remaining: 374ms
# 772:	learn: 0.1971718	total: 1.27s	remaining: 373ms
# 773:	learn: 0.1969293	total: 1.27s	remaining: 371ms
# 774:	learn: 0.1966869	total: 1.27s	remaining: 369ms
# 775:	learn: 0.1965329	total: 1.27s	remaining: 368ms
# 776:	learn: 0.1963955	total: 1.27s	remaining: 366ms
# 777:	learn: 0.1961896	total: 1.28s	remaining: 365ms
# 778:	learn: 0.1959681	total: 1.28s	remaining: 363ms
# 779:	learn: 0.1957864	total: 1.28s	remaining: 361ms
# 780:	learn: 0.1955514	total: 1.28s	remaining: 360ms
# 781:	learn: 0.1953307	total: 1.28s	remaining: 358ms
# 782:	learn: 0.1950637	total: 1.29s	remaining: 357ms
# 783:	learn: 0.1948729	total: 1.29s	remaining: 355ms
# 784:	learn: 0.1946402	total: 1.29s	remaining: 354ms
# 785:	learn: 0.1944652	total: 1.29s	remaining: 352ms
# 786:	learn: 0.1942650	total: 1.29s	remaining: 351ms
# 787:	learn: 0.1941197	total: 1.3s	remaining: 349ms
# 788:	learn: 0.1939409	total: 1.3s	remaining: 347ms
# 789:	learn: 0.1937554	total: 1.3s	remaining: 346ms
# 790:	learn: 0.1936030	total: 1.3s	remaining: 344ms
# 791:	learn: 0.1933557	total: 1.3s	remaining: 342ms
# 792:	learn: 0.1931661	total: 1.3s	remaining: 341ms
# 793:	learn: 0.1930019	total: 1.31s	remaining: 339ms
# 794:	learn: 0.1928688	total: 1.31s	remaining: 338ms
# 795:	learn: 0.1926753	total: 1.31s	remaining: 336ms
# 796:	learn: 0.1925223	total: 1.31s	remaining: 334ms
# 797:	learn: 0.1923050	total: 1.31s	remaining: 333ms
# 798:	learn: 0.1920811	total: 1.31s	remaining: 331ms
# 799:	learn: 0.1919445	total: 1.32s	remaining: 329ms
# 800:	learn: 0.1917364	total: 1.32s	remaining: 328ms
# 801:	learn: 0.1915287	total: 1.32s	remaining: 326ms
# 802:	learn: 0.1913419	total: 1.32s	remaining: 324ms
# 803:	learn: 0.1911603	total: 1.32s	remaining: 323ms
# 804:	learn: 0.1909494	total: 1.32s	remaining: 321ms
# 805:	learn: 0.1907124	total: 1.33s	remaining: 320ms
# 806:	learn: 0.1904008	total: 1.33s	remaining: 318ms
# 807:	learn: 0.1902176	total: 1.33s	remaining: 316ms
# 808:	learn: 0.1900312	total: 1.33s	remaining: 315ms
# 809:	learn: 0.1898775	total: 1.33s	remaining: 313ms
# 810:	learn: 0.1895924	total: 1.33s	remaining: 311ms
# 811:	learn: 0.1893897	total: 1.34s	remaining: 310ms
# 812:	learn: 0.1891976	total: 1.34s	remaining: 308ms
# 813:	learn: 0.1889927	total: 1.34s	remaining: 306ms
# 814:	learn: 0.1887834	total: 1.34s	remaining: 305ms
# 815:	learn: 0.1885564	total: 1.34s	remaining: 303ms
# 816:	learn: 0.1883468	total: 1.34s	remaining: 301ms
# 817:	learn: 0.1881591	total: 1.35s	remaining: 300ms
# 818:	learn: 0.1880207	total: 1.35s	remaining: 298ms
# 819:	learn: 0.1878272	total: 1.35s	remaining: 296ms
# 820:	learn: 0.1876310	total: 1.35s	remaining: 295ms
# 821:	learn: 0.1874447	total: 1.35s	remaining: 293ms
# 822:	learn: 0.1872590	total: 1.35s	remaining: 292ms
# 823:	learn: 0.1871099	total: 1.36s	remaining: 290ms
# 824:	learn: 0.1869285	total: 1.36s	remaining: 288ms
# 825:	learn: 0.1868087	total: 1.36s	remaining: 287ms
# 826:	learn: 0.1866253	total: 1.36s	remaining: 285ms
# 827:	learn: 0.1864820	total: 1.36s	remaining: 284ms
# 828:	learn: 0.1863535	total: 1.37s	remaining: 282ms
# 829:	learn: 0.1861547	total: 1.37s	remaining: 280ms
# 830:	learn: 0.1859795	total: 1.37s	remaining: 279ms
# 831:	learn: 0.1857503	total: 1.37s	remaining: 277ms
# 832:	learn: 0.1855804	total: 1.37s	remaining: 276ms
# 833:	learn: 0.1853663	total: 1.38s	remaining: 274ms
# 834:	learn: 0.1851502	total: 1.38s	remaining: 272ms
# 835:	learn: 0.1849876	total: 1.38s	remaining: 271ms
# 836:	learn: 0.1847980	total: 1.38s	remaining: 269ms
# 837:	learn: 0.1846131	total: 1.38s	remaining: 267ms
# 838:	learn: 0.1844659	total: 1.38s	remaining: 266ms
# 839:	learn: 0.1842832	total: 1.39s	remaining: 264ms
# 840:	learn: 0.1840174	total: 1.39s	remaining: 262ms
# 841:	learn: 0.1837856	total: 1.39s	remaining: 261ms
# 842:	learn: 0.1835857	total: 1.39s	remaining: 259ms
# 843:	learn: 0.1833795	total: 1.39s	remaining: 257ms
# 844:	learn: 0.1832486	total: 1.39s	remaining: 256ms
# 845:	learn: 0.1829900	total: 1.4s	remaining: 254ms
# 846:	learn: 0.1828215	total: 1.4s	remaining: 253ms
# 847:	learn: 0.1825408	total: 1.4s	remaining: 251ms
# 848:	learn: 0.1823334	total: 1.4s	remaining: 249ms
# 849:	learn: 0.1821539	total: 1.4s	remaining: 248ms
# 850:	learn: 0.1820027	total: 1.4s	remaining: 246ms
# 851:	learn: 0.1818051	total: 1.41s	remaining: 244ms
# 852:	learn: 0.1816500	total: 1.41s	remaining: 243ms
# 853:	learn: 0.1814587	total: 1.41s	remaining: 241ms
# 854:	learn: 0.1813066	total: 1.41s	remaining: 239ms
# 855:	learn: 0.1811233	total: 1.41s	remaining: 238ms
# 856:	learn: 0.1809228	total: 1.41s	remaining: 236ms
# 857:	learn: 0.1807850	total: 1.42s	remaining: 234ms
# 858:	learn: 0.1805844	total: 1.42s	remaining: 233ms
# 859:	learn: 0.1803781	total: 1.42s	remaining: 231ms
# 860:	learn: 0.1801279	total: 1.42s	remaining: 229ms
# 861:	learn: 0.1799185	total: 1.42s	remaining: 228ms
# 862:	learn: 0.1797305	total: 1.42s	remaining: 226ms
# 863:	learn: 0.1796122	total: 1.43s	remaining: 224ms
# 864:	learn: 0.1794199	total: 1.43s	remaining: 223ms
# 865:	learn: 0.1792516	total: 1.43s	remaining: 221ms
# 866:	learn: 0.1790237	total: 1.43s	remaining: 219ms
# 867:	learn: 0.1788115	total: 1.43s	remaining: 218ms
# 868:	learn: 0.1785926	total: 1.43s	remaining: 216ms
# 869:	learn: 0.1783114	total: 1.44s	remaining: 214ms
# 870:	learn: 0.1781232	total: 1.44s	remaining: 213ms
# 871:	learn: 0.1779252	total: 1.44s	remaining: 211ms
# 872:	learn: 0.1777912	total: 1.44s	remaining: 209ms
# 873:	learn: 0.1776115	total: 1.44s	remaining: 208ms
# 874:	learn: 0.1774866	total: 1.44s	remaining: 206ms
# 875:	learn: 0.1773438	total: 1.44s	remaining: 205ms
# 876:	learn: 0.1771606	total: 1.45s	remaining: 203ms
# 877:	learn: 0.1769831	total: 1.45s	remaining: 201ms
# 878:	learn: 0.1768251	total: 1.45s	remaining: 200ms
# 879:	learn: 0.1765747	total: 1.45s	remaining: 198ms
# 880:	learn: 0.1763570	total: 1.45s	remaining: 196ms
# 881:	learn: 0.1761541	total: 1.45s	remaining: 195ms
# 882:	learn: 0.1760242	total: 1.46s	remaining: 193ms
# 883:	learn: 0.1758375	total: 1.46s	remaining: 191ms
# 884:	learn: 0.1756453	total: 1.46s	remaining: 190ms
# 885:	learn: 0.1754841	total: 1.46s	remaining: 188ms
# 886:	learn: 0.1752760	total: 1.46s	remaining: 186ms
# 887:	learn: 0.1751011	total: 1.46s	remaining: 185ms
# 888:	learn: 0.1748947	total: 1.47s	remaining: 183ms
# 889:	learn: 0.1747644	total: 1.47s	remaining: 181ms
# 890:	learn: 0.1745877	total: 1.47s	remaining: 180ms
# 891:	learn: 0.1744224	total: 1.47s	remaining: 178ms
# 892:	learn: 0.1743059	total: 1.47s	remaining: 176ms
# 893:	learn: 0.1741113	total: 1.47s	remaining: 175ms
# 894:	learn: 0.1739291	total: 1.47s	remaining: 173ms
# 895:	learn: 0.1736486	total: 1.48s	remaining: 171ms
# 896:	learn: 0.1735230	total: 1.48s	remaining: 170ms
# 897:	learn: 0.1732943	total: 1.48s	remaining: 168ms
# 898:	learn: 0.1731438	total: 1.48s	remaining: 166ms
# 899:	learn: 0.1729907	total: 1.48s	remaining: 165ms
# 900:	learn: 0.1728358	total: 1.48s	remaining: 163ms
# 901:	learn: 0.1727069	total: 1.49s	remaining: 161ms
# 902:	learn: 0.1725921	total: 1.49s	remaining: 160ms
# 903:	learn: 0.1724802	total: 1.49s	remaining: 158ms
# 904:	learn: 0.1723685	total: 1.49s	remaining: 157ms
# 905:	learn: 0.1721629	total: 1.49s	remaining: 155ms
# 906:	learn: 0.1719425	total: 1.5s	remaining: 153ms
# 907:	learn: 0.1717753	total: 1.5s	remaining: 152ms
# 908:	learn: 0.1715615	total: 1.5s	remaining: 150ms
# 909:	learn: 0.1714115	total: 1.5s	remaining: 148ms
# 910:	learn: 0.1712226	total: 1.5s	remaining: 147ms
# 911:	learn: 0.1710234	total: 1.5s	remaining: 145ms
# 912:	learn: 0.1708005	total: 1.5s	remaining: 143ms
# 913:	learn: 0.1706397	total: 1.51s	remaining: 142ms
# 914:	learn: 0.1704423	total: 1.51s	remaining: 140ms
# 915:	learn: 0.1702796	total: 1.51s	remaining: 138ms
# 916:	learn: 0.1701402	total: 1.51s	remaining: 137ms
# 917:	learn: 0.1699397	total: 1.51s	remaining: 135ms
# 918:	learn: 0.1697654	total: 1.51s	remaining: 134ms
# 919:	learn: 0.1696317	total: 1.52s	remaining: 132ms
# 920:	learn: 0.1694886	total: 1.52s	remaining: 130ms
# 921:	learn: 0.1693127	total: 1.52s	remaining: 129ms
# 922:	learn: 0.1691244	total: 1.52s	remaining: 127ms
# 923:	learn: 0.1689759	total: 1.52s	remaining: 125ms
# 924:	learn: 0.1688566	total: 1.52s	remaining: 124ms
# 925:	learn: 0.1686440	total: 1.52s	remaining: 122ms
# 926:	learn: 0.1684767	total: 1.53s	remaining: 120ms
# 927:	learn: 0.1682647	total: 1.53s	remaining: 119ms
# 928:	learn: 0.1680817	total: 1.53s	remaining: 117ms
# 929:	learn: 0.1678844	total: 1.53s	remaining: 115ms
# 930:	learn: 0.1677343	total: 1.53s	remaining: 114ms
# 931:	learn: 0.1675647	total: 1.53s	remaining: 112ms
# 932:	learn: 0.1673400	total: 1.54s	remaining: 110ms
# 933:	learn: 0.1671463	total: 1.54s	remaining: 109ms
# 934:	learn: 0.1669218	total: 1.54s	remaining: 107ms
# 935:	learn: 0.1667414	total: 1.54s	remaining: 105ms
# 936:	learn: 0.1665626	total: 1.54s	remaining: 104ms
# 937:	learn: 0.1664781	total: 1.54s	remaining: 102ms
# 938:	learn: 0.1662985	total: 1.55s	remaining: 100ms
# 939:	learn: 0.1661276	total: 1.55s	remaining: 98.8ms
# 940:	learn: 0.1659395	total: 1.55s	remaining: 97.1ms
# 941:	learn: 0.1658358	total: 1.55s	remaining: 95.5ms
# 942:	learn: 0.1657076	total: 1.55s	remaining: 93.8ms
# 943:	learn: 0.1655945	total: 1.55s	remaining: 92.2ms
# 944:	learn: 0.1653973	total: 1.55s	remaining: 90.5ms
# 945:	learn: 0.1652978	total: 1.56s	remaining: 88.9ms
# 946:	learn: 0.1651407	total: 1.56s	remaining: 87.2ms
# 947:	learn: 0.1649518	total: 1.56s	remaining: 85.6ms
# 948:	learn: 0.1648123	total: 1.56s	remaining: 83.9ms
# 949:	learn: 0.1645241	total: 1.56s	remaining: 82.3ms
# 950:	learn: 0.1643316	total: 1.56s	remaining: 80.7ms
# 951:	learn: 0.1641898	total: 1.57s	remaining: 79ms
# 952:	learn: 0.1640569	total: 1.57s	remaining: 77.4ms
# 953:	learn: 0.1639508	total: 1.57s	remaining: 75.7ms
# 954:	learn: 0.1637671	total: 1.57s	remaining: 74.1ms
# 955:	learn: 0.1635871	total: 1.57s	remaining: 72.4ms
# 956:	learn: 0.1634646	total: 1.57s	remaining: 70.8ms
# 957:	learn: 0.1632922	total: 1.58s	remaining: 69.1ms
# 958:	learn: 0.1631310	total: 1.58s	remaining: 67.5ms
# 959:	learn: 0.1629833	total: 1.58s	remaining: 65.9ms
# 960:	learn: 0.1629350	total: 1.58s	remaining: 64.2ms
# 961:	learn: 0.1627710	total: 1.58s	remaining: 62.6ms
# 962:	learn: 0.1626381	total: 1.58s	remaining: 60.9ms
# 963:	learn: 0.1624197	total: 1.59s	remaining: 59.3ms
# 964:	learn: 0.1622838	total: 1.59s	remaining: 57.6ms
# 965:	learn: 0.1621281	total: 1.59s	remaining: 56ms
# 966:	learn: 0.1620093	total: 1.59s	remaining: 54.3ms
# 967:	learn: 0.1618286	total: 1.59s	remaining: 52.7ms
# 968:	learn: 0.1616513	total: 1.59s	remaining: 51ms
# 969:	learn: 0.1614528	total: 1.6s	remaining: 49.4ms
# 970:	learn: 0.1612364	total: 1.6s	remaining: 47.7ms
# 971:	learn: 0.1610905	total: 1.6s	remaining: 46.1ms
# 972:	learn: 0.1609907	total: 1.6s	remaining: 44.4ms
# 973:	learn: 0.1608046	total: 1.6s	remaining: 42.8ms
# 974:	learn: 0.1606520	total: 1.6s	remaining: 41.1ms
# 975:	learn: 0.1605537	total: 1.61s	remaining: 39.5ms
# 976:	learn: 0.1604542	total: 1.61s	remaining: 37.9ms
# 977:	learn: 0.1602622	total: 1.61s	remaining: 36.2ms
# 978:	learn: 0.1600691	total: 1.61s	remaining: 34.6ms
# 979:	learn: 0.1598707	total: 1.61s	remaining: 32.9ms
# 980:	learn: 0.1597565	total: 1.61s	remaining: 31.3ms
# 981:	learn: 0.1596163	total: 1.62s	remaining: 29.6ms
# 982:	learn: 0.1594096	total: 1.62s	remaining: 28ms
# 983:	learn: 0.1592618	total: 1.62s	remaining: 26.3ms
# 984:	learn: 0.1590876	total: 1.62s	remaining: 24.7ms
# 985:	learn: 0.1589210	total: 1.62s	remaining: 23ms
# 986:	learn: 0.1588288	total: 1.62s	remaining: 21.4ms
# 987:	learn: 0.1586660	total: 1.63s	remaining: 19.8ms
# 988:	learn: 0.1585637	total: 1.63s	remaining: 18.1ms
# 989:	learn: 0.1584192	total: 1.63s	remaining: 16.5ms
# 990:	learn: 0.1582784	total: 1.63s	remaining: 14.8ms
# 991:	learn: 0.1582088	total: 1.63s	remaining: 13.2ms
# 992:	learn: 0.1580538	total: 1.63s	remaining: 11.5ms
# 993:	learn: 0.1578651	total: 1.64s	remaining: 9.87ms
# 994:	learn: 0.1576951	total: 1.64s	remaining: 8.23ms
# 995:	learn: 0.1575174	total: 1.64s	remaining: 6.58ms
# 996:	learn: 0.1574141	total: 1.64s	remaining: 4.93ms
# 997:	learn: 0.1572795	total: 1.64s	remaining: 3.29ms
# 998:	learn: 0.1571101	total: 1.64s	remaining: 1.65ms
# 999:	learn: 0.1569769	total: 1.65s	remaining: 0us
# Classification_report of this Cat Boost is:
# Average Precision: 0.7272
# Average Recall: 0.7200
# Average F1-score: 0.7182

# %%
#Plot AUROC
plt.figure(figsize = (15,8))
plt.plot([0,1],[0,1],linestyle ="--",color= 'red',lw = 2,label = 'Chance',alpha = .8)
mean_tprs = np.mean(tprs, axis = 0)
mean_auc = auc(mean_fprs, mean_tprs)
std_auc = np.std(aucs)
std_tpr = np.std(tprs,axis = 0)
tprs_upper = np.minimum(mean_tprs + std_tpr, 1)
tprs_lower = np.maximum(mean_tprs - std_tpr,0)
plt.fill_between(mean_fprs,tprs_upper,tprs_lower,color = 'grey', alpha = .2, label = r'$\pm$ 1 std.dev.')

mean_tprs[-1] = 1
plt.plot(mean_fprs, mean_tprs, lw = 2, alpha =.8,color = 'navy',label =r'mean ROC (AUC ={:.2f} $\pm$ {:.2f})'.format(mean_auc,std_auc))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc = "lower right" )
plt.show()

# %%
#Plot PDF with Decision Threshold
plt.figure(figsize = (15,8))
sns.kdeplot(true_positive_prob, label = 'True Positive', color = 'b')
sns.kdeplot(false_positive_prob, label = 'False Positive', color = 'r')
decision_threshold = 0.5
plt.axvline(x = decision_threshold, color = 'g', label = f'Decision Threshold {decision_threshold}') 
plt.xlabel("Predicted Probability")
plt.ylabel("PDF")
plt.title("PDF with Decision Threshold")
plt.legend(loc = "upper right")
